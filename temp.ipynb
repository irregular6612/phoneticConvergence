# %%
import numpy as np

# %%
27/8.0 - 5.0/8.0*np.log2(5.0)
# Out:
# np.float64(1.9237949406953987)

# %%
1/2 + 5/4 + 15/8 + 35/16
# Out:
# 5.8125

# %%
-(0.44*np.log2(0.44) + 0.56*np.log2(0.56))
# Out:
# np.float64(0.9895875212220556)

# %%
p0 = 0.6
p1 = 0.1
p2 = 0.2
# 0, 0
print((1-p0)*(1-p1)*(1-p2) + p0*p1*p2)
# 0, 1
print((1-p0)*(1-p1)*p2 + p0*p1*(1-p2))
# 1, 0
print((1-p0)*p1*(1-p2) + p0*(1-p1)*p2)
# 1, 1
print((1-p0)*p1*p2 + p0*(1-p1)*(1-p2))
# Out:
# 0.30000000000000004
# 0.12000000000000001
# 0.14
# 0.44000000000000006

# %%
-(0.3*np.log2(0.3) + 0.12*np.log2(0.12) + 0.14*np.log2(0.14) + 0.44*np.log2(0.44))
# Out:
# np.float64(1.806413909717155)
