# %%
import os 
import numpy as np
import pandas as pd
import librosa
from pathlib import Path

# %%
left_data_path = os.path.join(os.path.dirname(os.path.dirname(Path.cwd())), 'data', 'experiment_data', 'results-KFA-left')
left_data_path
# Out:
# '/Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left'

# %%
resultPath = left_data_path
participant_list = [file for file in os.listdir(resultPath) if "participant" in file]
participant_list.sort()
participant_list
# Out:
# ['participant_LY043(X)',
#  'participant_LY058',
#  'participant_LY059(X)',
#  'participant_LY060',
#  'participant_LY061',
#  'participant_LY062']

# %%
def create_textgrid(filename, duration, intervals):
    """
    TextGrid 파일을 생성하는 함수
    
    Parameters:
    - filename: 저장할 파일 경로
    - duration: 음원 길이 (초)
    - intervals: [(시작시간, 종료시간, 전사내용), ...] 형식의 리스트
    """
    with open(filename, 'w', encoding='utf-8') as f:
        # 헤더 작성
        f.write('File type = "ooTextFile"\n')
        f.write('Object class = "TextGrid"\n\n')
        
        # 시간 정보
        f.write(f'xmin = 0\n')
        f.write(f'xmax = {duration}\n')
        f.write('tiers? <exists>\n')
        f.write('size = 1\n')
        
        # IntervalTier 정보
        f.write('item []:\n')
        f.write('    item [1]:\n')
        f.write('        class = "IntervalTier"\n')
        f.write('        name = "transcription"\n')
        f.write(f'        xmin = 0\n')
        f.write(f'        xmax = {duration}\n')
        f.write(f'        intervals: size = {len(intervals)}\n')
        
        # 각 구간 정보 작성
        for i, (start, end, text) in enumerate(intervals, 1):
            f.write(f'        intervals [{i}]:\n')
            f.write(f'            xmin = {start}\n')
            f.write(f'            xmax = {end}\n')
            f.write(f'            text = "{text}"\n')

# 사용 예시
intervals = [
    (0.0, 1.5, "안녕하세요"),
    (1.5, 3.0, "반갑습니다"),
    (3.0, 4.5, "오늘도 좋은 하루 되세요")
]

#create_textgrid(os.path.join("../../../../Desktop/results/participant_LY001(-)", "test.TextGrid"), 4.5, intervals)

# %%
def get_wav_duration(wav_path):
    """
    WAV 파일의 길이를 초 단위로 반환
    """
    duration = librosa.get_duration(path=wav_path)
    return duration

# %%
for participant in participant_list:
    
    participant_path = os.path.join(resultPath, participant)
    file_list = os.listdir(participant_path)
    
    if len(file_list) == 0:
        raise ValueError(f"No files found in {participant_path}")
    
    excel_path = [file for file in file_list if file.endswith(".xlsx")]
    if len(excel_path) == 0:
        raise ValueError(f"No excel file found in {participant_path}")
    elif len(excel_path) > 1:
        raise ValueError(f"Multiple excel files found in {participant_path}")
    excel_path = os.path.join(participant_path, excel_path[0])
    
    # read excel file
    excel_file = pd.ExcelFile(excel_path)
    sheet_names = excel_file.sheet_names
    for sheet_name in sheet_names:
        transcript = ""
        if not("Stage" in sheet_name):
            continue

        excel_df = pd.read_excel(excel_path, sheet_name=sheet_name)
        target_column_name = "단어" if "단어" in excel_df.columns else "음성파일"

        if target_column_name == "단어":
            transcript = excel_df[target_column_name].to_string(index=False).replace("\n", " ")
        elif target_column_name == "음성파일":
            transcript = excel_df[target_column_name].to_string(index=False).replace(".wav\n", " ").replace(".wav", "")

        #print(transcript)
        sheet_name = sheet_name.lower()
        file_list = os.listdir(participant_path)
        wav_file_name = [file for file in file_list if sheet_name.lower() in file.lower() and file.endswith(".wav")][0]
        
        transcriptPath = os.path.join(participant_path, wav_file_name.replace(".wav", ".txt"))
        print(transcriptPath)
        
        with open(transcriptPath, "w") as f:
            f.write(transcript)

        """
        wav_file_name = [file for file in file_list if sheet_name.lower() in file.lower() and file.endswith(".wav")][0]
        textGrid_name = wav_file_name.replace(".wav", ".TextGrid")
        textGrid_path = os.path.join(participant_path, textGrid_name)
        duration = get_wav_duration(os.path.join(participant_path, wav_file_name))
        start_time = 0.0
        end_time = duration
        intervals = [(start_time, end_time, transcript)]
        
        create_textgrid(textGrid_path, duration, intervals)
        """
# Out:
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY043(X)/43_stage1_20250502_1328.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY043(X)/43_stage2_20250502_1328.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY043(X)/43_stage3_20250502_1330.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY043(X)/43_stage4_20250502_1330.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY043(X)/43_stage5_20250502_1335.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY043(X)/43_stage6_20250502_1339.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY058/58_stage1_20250621_1536.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY058/58_stage2_20250621_1537.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY058/58_stage3_20250621_1539.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY058/58_stage4_20250621_1540.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY058/58_stage5_20250621_1548.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY058/58_stage6_20250621_1554.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY059(X)/59_stage1_20250722_1750.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY059(X)/59_stage2_20250722_1750.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY059(X)/59_stage3_20250722_1752.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY059(X)/59_stage4_20250722_1752.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY059(X)/59_stage5_20250722_1757.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY059(X)/59_stage6_20250722_1802.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY060/60_stage1_20250716_1124.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY060/60_stage2_20250716_1124.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY060/60_stage3_20250716_1126.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY060/60_stage4_20250716_1126.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY060/60_stage5_20250716_1132.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY060/60_stage6_20250716_1136.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY061/61_stage1_20250727_1402.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY061/61_stage2_20250727_1403.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY061/61_stage3_20250727_1404.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY061/61_stage4_20250727_1404.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY061/61_stage5_20250727_1409.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY061/61_stage6_20250727_1413.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY062/LY062_stage1_20250725_1126.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY062/LY062_stage2_20250725_1126.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY062/LY062_stage3_20250725_1128.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY062/LY062_stage4_20250725_1128.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY062/LY062_stage5_20250725_1133.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/data/experiment_data/results-KFA-left/participant_LY062/LY062_stage6_20250725_1138.txt

# %%
class TextGridReader:
    def __init__(self, textgrid_path):
        self.textgrid_path = textgrid_path
        self.tiers_data = {}
        self.file_info = {}
        
    def read(self):
        """
        TextGrid 파일을 읽어서 구조화된 데이터로 변환
        """
        with open(self.textgrid_path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
            
            # 파일 정보 읽기
            self._read_file_info(lines)
            
            # tier 정보 읽기
            self._read_tiers(lines)
            
        return self.tiers_data
    
    def _read_file_info(self, lines):
        """
        파일의 기본 정보 읽기
        """
        for line in lines:
            line = line.strip()
            if '=' in line:
                key, value = line.split('=', 1)
                key = key.strip()
                value = value.strip().strip('"')
                self.file_info[key] = value
    
    def _read_tiers(self, lines):
        """
        tier 정보 읽기
        """
        current_tier = None
        current_intervals = []
        reading_interval = False
        interval_data = {}
        
        for line in lines:
            line = line.strip()
            
            # tier 시작
            if 'name = "' in line:
                if current_tier is not None:
                    self.tiers_data[current_tier] = current_intervals
                current_tier = line.split('"')[1]
                current_intervals = []
                reading_interval = False
            
            # interval 시작
            elif 'intervals [' in line:
                reading_interval = True
                interval_data = {}
            
            # interval 데이터 읽기
            elif reading_interval and '=' in line:
                key, value = line.split('=', 1)
                key = key.strip()
                value = value.strip().strip('"')
                interval_data[key] = value
                
                # interval 완성
                if 'text' in interval_data:
                    start = float(interval_data['xmin'])
                    end = float(interval_data['xmax'])
                    text = interval_data['text']
                    current_intervals.append((start, end, text))
                    reading_interval = False
        
        # 마지막 tier 추가
        if current_tier is not None:
            self.tiers_data[current_tier] = current_intervals
    
    def get_tier_names(self):
        """
        tier 이름 목록 반환
        """
        return list(self.tiers_data.keys())
    
    def get_intervals_by_tier(self, tier_name):
        """
        특정 tier의 interval 목록 반환
        """
        return self.tiers_data.get(tier_name, [])
    
    def get_total_duration(self):
        """
        전체 음성 길이 반환
        """
        return float(self.file_info.get('xmax', 0))

# %%
import parselmouth
import numpy as np

def get_average_formants(wav_path, start_time, end_time, time_step=0.01):
    """
    특정 구간의 평균 포먼트 값 계산
    
    Parameters:
    - wav_path: WAV 파일 경로
    - start_time: 시작 시간 (초)
    - end_time: 종료 시간 (초)
    - time_step: 시간 간격 (초)
    
    Returns:
    - avg_f1, avg_f2: 평균 F1, F2 값 (Hz)
    """
    # 음성 파일 로드
    snd = parselmouth.Sound(wav_path)

    # Formant 객체 생성 (Praat의 Formant settings와 동일한 파라미터 사용)
    formant = snd.to_formant_burg(
        max_number_of_formants=5,  # Praat 기본값: 5
        maximum_formant=5500,      # Praat 기본값: 5500 Hz (여성)
        window_length=0.025,       # Praat 기본값: 0.025초
        pre_emphasis_from=50,      # Praat 기본값: 50 Hz
        time_step=0.025/4 # 시간 간격
    )
    
    # 시간 포인트 생성
    time_points = np.arange(start_time, end_time, time_step)
    
    # 각 시간 포인트에서의 F1, F2 값 수집
    f1_values = []
    f2_values = []
    
    for time in time_points:
        f1 = formant.get_value_at_time(1, time)
        f2 = formant.get_value_at_time(2, time)
        
        # 유효한 값만 수집 (NaN이 아닌 경우)
        if not np.isnan(f1):
            f1_values.append(f1)
        if not np.isnan(f2):
            f2_values.append(f2)
    
    # 평균값 계산
    avg_f1 = np.mean(f1_values) if f1_values else None
    avg_f2 = np.mean(f2_values) if f2_values else None
    
    return avg_f1, avg_f2

# %%
def detect_formants(participant_path, textGrid_name):
    if not os.path.exists(participant_path):
        raise ValueError(f"없는 디렉토리: {participant_path}")

    textgrid_path = os.path.join(participant_path, "output-new", textGrid_name)
    reader = TextGridReader(textgrid_path)
    try:
        # TextGrid 파일 읽기
        tiers_data = reader.read()
        
        # 파일 정보 출력
        print("파일 정보:")
        print(f"전체 길이: {reader.get_total_duration():.3f}초")
        print(f"Tier 목록: {reader.get_tier_names()}")
        print("\n" + "="*50)
        
        # 각 tier의 내용 출력
        phoneme_cnt = 0
        phonemes = []
        f1_values = []
        f2_values = []
        for tier_name in reader.get_tier_names():
            # 단어를 분석하는게 아니라, 모음만 포먼트 딸거니까,,
            if tier_name == "words":
                continue

            print(f"\nTier: {tier_name}")
            print("-"*30)
            
            intervals = reader.get_intervals_by_tier(tier_name)
            print(type(intervals))
            for start, end, text in intervals:
                if text == "":
                    continue
            
                if text == "spn":
                    phoneme_cnt+=2
                    print(f"구간 {start:.2f}-{end:.2f}초의 평균 포먼트 값:")
                    print("detection failed.")
                    print(f"F1: None")
                    print(f"F2: None")
                    phonemes.append(None)
                    phonemes.append(None)
                    f1_values.append(None)
                    f1_values.append(None)
                    f2_values.append(None)
                    f2_values.append(None)
                    continue


                elif text not in ["ɐ","ɐː", "ɛ", "ɛː", "i", "iː", "o", "oː", "u", "uː"]:
                    continue
                print(f"phoneme: {text}")
                phoneme_cnt+=1
                wav_file_name = textGrid_name.replace(".TextGrid", ".wav")
                avg_f1, avg_f2 = get_average_formants(os.path.join(participant_path, wav_file_name), start, end)
    
                if avg_f1 is not None and avg_f2 is not None:
                    print(f"구간 {start:.2f}-{end:.2f}초의 평균 포먼트 값:")
                    print(f"F1: {avg_f1:.2f} Hz")
                    print(f"F2: {avg_f2:.2f} Hz")
                    phonemes.append(text)
                    f1_values.append(avg_f1)
                    f2_values.append(avg_f2)
                else:
                    print("유효한 포먼트 값을 찾을 수 없습니다.")
                    phonemes.append(None)
                    f1_values.append(None)
                    f2_values.append(None)
                
                print("-"*20)
        print(f"total detected phonemes: {phoneme_cnt}")
        pandas_data = pd.DataFrame({
            "phoneme": phonemes,
            "f1": f1_values,
            "f2": f2_values
        })
        pandas_data.to_csv(os.path.join(participant_path, textGrid_name.replace(".TextGrid", ".csv")), index=False)
        
    except Exception as e:
        print(f"에러 발생: {str(e)}")

# %%
expPath = "../../../../Desktop/results"
participant_list = [file for file in os.listdir(expPath) if "participant_LY" in file]
participant_list.sort()

# %%
for participant in participant_list:
    participant_path = os.path.join(expPath, participant)
    file_list = os.listdir(participant_path)
    
    if len(file_list) == 0:
        print(ValueError(f"No files found in {participant_path}"))
        continue

    textgrids_path = os.path.join(participant_path, "output-new")
    textgrids_list = os.listdir(textgrids_path)
    textgrids_list = [file for file in textgrids_list if file.endswith(".TextGrid")]
    textgrids_list.sort()
    for textgrid in textgrids_list:
        detect_formants(participant_path, textgrid)
# Out:
# 파일 정보:
# 전체 길이: 7.656초
# Tier 목록: ['words', 'phones']
#
# ==================================================
#
# Tier: phones
# ------------------------------
# <class 'list'>
# 구간 2.34-2.96초의 평균 포먼트 값:
# detection failed.
# F1: None
# F2: None
# phoneme: i
# 구간 5.15-5.39초의 평균 포먼트 값:
# F1: 1344.16 Hz
# F2: 2616.98 Hz
# --------------------
# 구간 6.59-7.13초의 평균 포먼트 값:
# detection failed.
# F1: None
# F2: None
# total detected phonemes: 5
# 파일 정보:
# 전체 길이: 68.587초
# Tier 목록: ['words', 'phones']
#
# ==================================================
#
# Tier: phones
# ------------------------------
# <class 'list'>
# phoneme: oː
# 구간 1.97-2.00초의 평균 포먼트 값:
# F1: 518.84 Hz
# F2: 1116.06 Hz
# --------------------
# phoneme: u
# 구간 2.28-2.51초의 평균 포먼트 값:
# F1: 520.32 Hz
# F2: 2417.09 Hz
# --------------------
# phoneme: ɐ
# 구간 3.31-3.37초의 평균 포먼트 값:
# F1: 975.47 Hz
# F2: 1314.75 Hz
# --------------------
# phoneme: i
# 구간 3.67-3.92초의 평균 포먼트 값:
# F1: 806.48 Hz
# F2: 2467.52 Hz
# --------------------
# phoneme: ɐ
# 구간 4.84-5.02초의 평균 포먼트 값:
# F1: 902.03 Hz
# F2: 1157.42 Hz
# --------------------
# phoneme: u
# 구간 5.15-5.23초의 평균 포먼트 값:
# F1: 881.84 Hz
# F2: 2449.10 Hz
# --------------------
# phoneme: ɛː
# 구간 6.42-6.49초의 평균 포먼트 값:
# F1: 497.75 Hz
# F2: 1851.61 Hz
# --------------------
# phoneme: u
# 구간 6.78-6.88초의 평균 포먼트 값:
# F1: 931.65 Hz
# F2: 2004.75 Hz
# --------------------
# phoneme: ɛː
# 구간 7.99-8.17초의 평균 포먼트 값:
# F1: 608.14 Hz
# F2: 1859.24 Hz
# --------------------
# phoneme: o
# 구간 8.24-8.39초의 평균 포먼트 값:
# F1: 597.63 Hz
# F2: 2328.19 Hz
# --------------------
# phoneme: ɛː
# 구간 9.28-9.35초의 평균 포먼트 값:
# F1: 457.14 Hz
# F2: 1998.35 Hz
# --------------------
# phoneme: ɛː
# 구간 9.60-9.85초의 평균 포먼트 값:
# F1: 430.92 Hz
# F2: 1975.80 Hz
# --------------------
# phoneme: o
# 구간 10.67-10.95초의 평균 포먼트 값:
# F1: 663.88 Hz
# F2: 2341.71 Hz
# --------------------
# phoneme: ɐ
# 구간 10.95-11.11초의 평균 포먼트 값:
# F1: 793.36 Hz
# F2: 1780.75 Hz
# --------------------
# phoneme: ɛː
# 구간 12.03-12.26초의 평균 포먼트 값:
# F1: 467.87 Hz
# F2: 1966.00 Hz
# --------------------
# phoneme: i
# 구간 12.35-12.46초의 평균 포먼트 값:
# F1: 1646.73 Hz
# F2: 2852.12 Hz
# --------------------
# phoneme: u
# 구간 13.59-13.64초의 평균 포먼트 값:
# F1: 653.56 Hz
# F2: 1987.35 Hz
# --------------------
# phoneme: i
# 구간 13.92-14.13초의 평균 포먼트 값:
# F1: 767.58 Hz
# F2: 2506.18 Hz
# --------------------
# phoneme: ɐ
# 구간 15.06-15.12초의 평균 포먼트 값:
# F1: 812.01 Hz
# F2: 1313.09 Hz
# --------------------
# phoneme: o
# 구간 15.38-15.52초의 평균 포먼트 값:
# F1: 628.42 Hz
# F2: 2144.31 Hz
# --------------------
# phoneme: iː
# 구간 16.43-16.63초의 평균 포먼트 값:
# F1: 1448.71 Hz
# F2: 2817.16 Hz
# --------------------
# phoneme: ɛː
# 구간 16.70-16.93초의 평균 포먼트 값:
# F1: 508.48 Hz
# F2: 1972.39 Hz
# --------------------
# phoneme: ɐ
# 구간 17.86-17.90초의 평균 포먼트 값:
# F1: 880.14 Hz
# F2: 1303.39 Hz
# --------------------
# phoneme: o
# 구간 18.16-18.27초의 평균 포먼트 값:
# F1: 578.33 Hz
# F2: 1346.89 Hz
# --------------------
# phoneme: ɛː
# 구간 19.20-19.38초의 평균 포먼트 값:
# F1: 689.70 Hz
# F2: 1965.26 Hz
# --------------------
# phoneme: ɐ
# 구간 19.49-19.60초의 평균 포먼트 값:
# F1: 779.74 Hz
# F2: 1179.13 Hz
# --------------------
# phoneme: ɐ
# 구간 20.50-20.60초의 평균 포먼트 값:
# F1: 819.72 Hz
# F2: 1484.66 Hz
# --------------------
# phoneme: i
# 구간 20.82-21.06초의 평균 포먼트 값:
# F1: 513.65 Hz
# F2: 2390.63 Hz
# --------------------
# phoneme: u
# 구간 21.93-21.96초의 평균 포먼트 값:
# F1: 786.65 Hz
# F2: 2713.61 Hz
# --------------------
# phoneme: u
# 구간 21.96-22.33초의 평균 포먼트 값:
# F1: 606.34 Hz
# F2: 2283.55 Hz
# --------------------
# phoneme: o
# 구간 23.29-23.33초의 평균 포먼트 값:
# F1: 580.06 Hz
# F2: 2109.21 Hz
# --------------------
# phoneme: ɛː
# 구간 23.59-23.85초의 평균 포먼트 값:
# F1: 563.05 Hz
# F2: 2010.86 Hz
# --------------------
# phoneme: o
# 구간 24.64-24.71초의 평균 포먼트 값:
# F1: 685.40 Hz
# F2: 1779.83 Hz
# --------------------
# phoneme: i
# 구간 24.96-25.07초의 평균 포먼트 값:
# F1: 1589.87 Hz
# F2: 2892.12 Hz
# --------------------
# phoneme: oː
# 구간 26.14-26.33초의 평균 포먼트 값:
# F1: 731.13 Hz
# F2: 2576.73 Hz
# --------------------
# phoneme: o
# 구간 26.41-26.71초의 평균 포먼트 값:
# F1: 656.38 Hz
# F2: 2403.11 Hz
# --------------------
# phoneme: o
# 구간 27.58-27.71초의 평균 포먼트 값:
# F1: 538.62 Hz
# F2: 2131.53 Hz
# --------------------
# phoneme: i
# 구간 27.93-28.16초의 평균 포먼트 값:
# F1: 1029.72 Hz
# F2: 2574.51 Hz
# --------------------
# phoneme: ɐ
# 구간 29.01-29.07초의 평균 포먼트 값:
# F1: 780.56 Hz
# F2: 1402.01 Hz
# --------------------
# phoneme: ɐ
# 구간 29.35-29.60초의 평균 포먼트 값:
# F1: 789.82 Hz
# F2: 1216.71 Hz
# --------------------
# phoneme: ɛː
# 구간 30.39-30.47초의 평균 포먼트 값:
# F1: 482.15 Hz
# F2: 1899.83 Hz
# --------------------
# phoneme: i
# 구간 30.76-30.82초의 평균 포먼트 값:
# F1: 914.01 Hz
# F2: 2543.83 Hz
# --------------------
# phoneme: ɛː
# 구간 31.81-32.02초의 평균 포먼트 값:
# F1: 483.82 Hz
# F2: 1926.19 Hz
# --------------------
# phoneme: u
# 구간 32.10-32.14초의 평균 포먼트 값:
# F1: 816.32 Hz
# F2: 1692.98 Hz
# --------------------
# phoneme: i
# 구간 33.06-33.29초의 평균 포먼트 값:
# F1: 933.05 Hz
# F2: 2521.26 Hz
# --------------------
# phoneme: i
# 구간 33.35-33.57초의 평균 포먼트 값:
# F1: 383.34 Hz
# F2: 2250.81 Hz
# --------------------
# phoneme: i
# 구간 34.33-34.45초의 평균 포먼트 값:
# F1: 283.55 Hz
# F2: 2039.95 Hz
# --------------------
# phoneme: o
# 구간 34.64-34.79초의 평균 포먼트 값:
# F1: 522.08 Hz
# F2: 2205.46 Hz
# --------------------
# phoneme: o
# 구간 35.63-35.66초의 평균 포먼트 값:
# F1: 536.40 Hz
# F2: 2211.93 Hz
# --------------------
# phoneme: o
# 구간 35.92-36.09초의 평균 포먼트 값:
# F1: 594.89 Hz
# F2: 2371.21 Hz
# --------------------
# phoneme: ɐ
# 구간 36.97-37.01초의 평균 포먼트 값:
# F1: 725.74 Hz
# F2: 1665.98 Hz
# --------------------
# phoneme: ɐ
# 구간 37.25-37.43초의 평균 포먼트 값:
# F1: 774.54 Hz
# F2: 1382.29 Hz
# --------------------
# phoneme: i
# 구간 38.32-38.36초의 평균 포먼트 값:
# F1: 617.77 Hz
# F2: 2408.73 Hz
# --------------------
# phoneme: i
# 구간 38.58-38.75초의 평균 포먼트 값:
# F1: 707.56 Hz
# F2: 2474.20 Hz
# --------------------
# phoneme: u
# 구간 39.59-39.81초의 평균 포먼트 값:
# F1: 907.25 Hz
# F2: 2102.08 Hz
# --------------------
# phoneme: i
# 구간 39.89-40.02초의 평균 포먼트 값:
# F1: 1095.63 Hz
# F2: 2554.35 Hz
# --------------------
# phoneme: o
# 구간 40.79-40.86초의 평균 포먼트 값:
# F1: 644.91 Hz
# F2: 2175.18 Hz
# --------------------
# phoneme: ɐ
# 구간 41.09-41.24초의 평균 포먼트 값:
# F1: 690.70 Hz
# F2: 1361.55 Hz
# --------------------
# phoneme: oː
# 구간 42.05-42.21초의 평균 포먼트 값:
# F1: 562.56 Hz
# F2: 2237.81 Hz
# --------------------
# phoneme: u
# 구간 42.30-42.44초의 평균 포먼트 값:
# F1: 656.91 Hz
# F2: 1275.24 Hz
# --------------------
# phoneme: i
# 구간 43.37-43.42초의 평균 포먼트 값:
# F1: 479.06 Hz
# F2: 1929.07 Hz
# --------------------
# phoneme: ɛː
# 구간 43.69-43.80초의 평균 포먼트 값:
# F1: 554.42 Hz
# F2: 2071.31 Hz
# --------------------
# phoneme: o
# 구간 44.72-44.81초의 평균 포먼트 값:
# F1: 802.50 Hz
# F2: 1855.34 Hz
# --------------------
# phoneme: ɛː
# 구간 45.04-45.31초의 평균 포먼트 값:
# F1: 435.25 Hz
# F2: 2085.76 Hz
# --------------------
# phoneme: u
# 구간 46.09-46.12초의 평균 포먼트 값:
# F1: 853.99 Hz
# F2: 2116.94 Hz
# --------------------
# phoneme: ɛː
# 구간 46.40-46.57초의 평균 포먼트 값:
# F1: 464.21 Hz
# F2: 1892.61 Hz
# --------------------
# phoneme: u
# 구간 47.46-47.51초의 평균 포먼트 값:
# F1: 681.17 Hz
# F2: 1900.19 Hz
# --------------------
# phoneme: ɐ
# 구간 47.77-47.88초의 평균 포먼트 값:
# F1: 772.97 Hz
# F2: 1339.38 Hz
# --------------------
# phoneme: ɛː
# 구간 48.74-48.87초의 평균 포먼트 값:
# F1: 458.14 Hz
# F2: 1945.85 Hz
# --------------------
# phoneme: o
# 구간 48.98-49.25초의 평균 포먼트 값:
# F1: 576.01 Hz
# F2: 1994.82 Hz
# --------------------
# phoneme: u
# 구간 50.03-50.06초의 평균 포먼트 값:
# F1: 412.89 Hz
# F2: 1418.92 Hz
# --------------------
# phoneme: o
# 구간 50.32-50.57초의 평균 포먼트 값:
# F1: 527.72 Hz
# F2: 2080.43 Hz
# --------------------
# phoneme: u
# 구간 51.30-51.34초의 평균 포먼트 값:
# F1: 580.90 Hz
# F2: 2073.17 Hz
# --------------------
# phoneme: ɛː
# 구간 51.58-51.83초의 평균 포먼트 값:
# F1: 503.49 Hz
# F2: 2066.37 Hz
# --------------------
# phoneme: i
# 구간 52.61-52.66초의 평균 포먼트 값:
# F1: 243.05 Hz
# F2: 1888.20 Hz
# --------------------
# phoneme: ɐ
# 구간 52.93-53.12초의 평균 포먼트 값:
# F1: 761.27 Hz
# F2: 1524.22 Hz
# --------------------
# phoneme: ɐ
# 구간 53.84-53.92초의 평균 포먼트 값:
# F1: 746.60 Hz
# F2: 1462.42 Hz
# --------------------
# phoneme: ɛː
# 구간 54.13-54.28초의 평균 포먼트 값:
# F1: 423.12 Hz
# F2: 1938.46 Hz
# --------------------
# phoneme: ɐ
# 구간 55.12-55.30초의 평균 포먼트 값:
# F1: 882.17 Hz
# F2: 1591.29 Hz
# --------------------
# phoneme: ɛː
# 구간 55.35-55.63초의 평균 포먼트 값:
# F1: 506.62 Hz
# F2: 2162.26 Hz
# --------------------
# phoneme: ɐ
# 구간 56.38-56.45초의 평균 포먼트 값:
# F1: 929.64 Hz
# F2: 1240.03 Hz
# --------------------
# phoneme: u
# 구간 56.69-56.90초의 평균 포먼트 값:
# F1: 698.28 Hz
# F2: 2149.57 Hz
# --------------------
# phoneme: i
# 구간 57.80-57.86초의 평균 포먼트 값:
# F1: 1216.29 Hz
# F2: 2668.73 Hz
# --------------------
# phoneme: ɐ
# 구간 58.09-58.35초의 평균 포먼트 값:
# F1: 728.27 Hz
# F2: 1319.76 Hz
# --------------------
# phoneme: ɛː
# 구간 59.12-59.16초의 평균 포먼트 값:
# F1: 953.30 Hz
# F2: 2000.87 Hz
# --------------------
# phoneme: ɛː
# 구간 59.44-59.64초의 평균 포먼트 값:
# F1: 421.41 Hz
# F2: 1964.70 Hz
# --------------------
# phoneme: uː
# 구간 60.46-60.64초의 평균 포먼트 값:
# F1: 658.58 Hz
# F2: 2313.08 Hz
# --------------------
# phoneme: ɐ
# 구간 60.74-60.93초의 평균 포먼트 값:
# F1: 879.67 Hz
# F2: 953.14 Hz
# --------------------
# phoneme: u
# 구간 61.64-61.86초의 평균 포먼트 값:
# F1: 740.60 Hz
# F2: 2194.04 Hz
# --------------------
# phoneme: u
# 구간 61.91-61.99초의 평균 포먼트 값:
# F1: 637.21 Hz
# F2: 2270.70 Hz
# --------------------
# phoneme: i
# 구간 62.88-62.92초의 평균 포먼트 값:
# F1: 283.35 Hz
# F2: 1970.09 Hz
# --------------------
# phoneme: o
# 구간 63.17-63.29초의 평균 포먼트 값:
# F1: 733.88 Hz
# F2: 2273.51 Hz
# --------------------
# phoneme: u
# 구간 64.12-64.32초의 평균 포먼트 값:
# F1: 615.66 Hz
# F2: 2288.09 Hz
# --------------------
# phoneme: o
# 구간 64.43-64.48초의 평균 포먼트 값:
# F1: 747.58 Hz
# F2: 1770.23 Hz
# --------------------
# phoneme: i
# 구간 65.48-65.69초의 평균 포먼트 값:
# F1: 333.87 Hz
# F2: 2174.02 Hz
# --------------------
# phoneme: u
# 구간 65.75-65.89초의 평균 포먼트 값:
# F1: 798.11 Hz
# F2: 2472.39 Hz
# --------------------
# phoneme: ɛː
# 구간 66.72-66.94초의 평균 포먼트 값:
# F1: 487.11 Hz
# F2: 1870.23 Hz
# --------------------
# phoneme: ɐ
# 구간 67.05-67.28초의 평균 포먼트 값:
# F1: 789.70 Hz
# F2: 1602.44 Hz
# --------------------
# phoneme: i
# 구간 68.08-68.12초의 평균 포먼트 값:
# F1: 494.45 Hz
# F2: 2028.43 Hz
# --------------------
# phoneme: u
# 구간 68.41-68.50초의 평균 포먼트 값:
# F1: 886.41 Hz
# F2: 2235.70 Hz
# --------------------
# total detected phonemes: 100
# 파일 정보:
# 전체 길이: 30.819초
# Tier 목록: ['words', 'phones']
#
# ==================================================
#
# Tier: phones
# ------------------------------
# <class 'list'>
# 구간 3.52-4.16초의 평균 포먼트 값:
# detection failed.
# F1: None
# F2: None
# 구간 7.05-7.67초의 평균 포먼트 값:
# detection failed.
# F1: None
# F2: None
# phoneme: i
# 구간 10.44-10.72초의 평균 포먼트 값:
# F1: 628.70 Hz
# F2: 2320.90 Hz
# --------------------
# phoneme: i
# 구간 14.12-14.43초의 평균 포먼트 값:
# F1: 625.40 Hz
# F2: 2278.98 Hz
# --------------------
# 구간 16.95-17.18초의 평균 포먼트 값:
# detection failed.
# F1: None
# F2: None
# 구간 17.30-17.65초의 평균 포먼트 값:
# detection failed.
# F1: None
# F2: None
# 구간 20.17-20.85초의 평균 포먼트 값:
# detection failed.
# F1: None
# F2: None
# 구간 23.51-24.21초의 평균 포먼트 값:
# detection failed.
# F1: None
# F2: None
# phoneme: i
# 구간 27.06-27.10초의 평균 포먼트 값:
# F1: 862.20 Hz
# F2: 2006.71 Hz
# --------------------
# total detected phonemes: 15
# 파일 정보:
# 전체 길이: 295.325초
# Tier 목록: ['words', 'phones']
#
# ==================================================
#
# Tier: phones
# ------------------------------
# <class 'list'>
# phoneme: i
# 구간 3.73-3.77초의 평균 포먼트 값:
# F1: 506.42 Hz
# F2: 1995.60 Hz
# --------------------
# phoneme: ɛː
# 구간 4.01-4.09초의 평균 포먼트 값:
# F1: 482.37 Hz
# F2: 1955.94 Hz
# --------------------
# phoneme: i
# 구간 6.31-6.38초의 평균 포먼트 값:
# F1: 308.53 Hz
# F2: 1928.73 Hz
# --------------------
# phoneme: ɐ
# 구간 6.61-6.85초의 평균 포먼트 값:
# F1: 760.32 Hz
# F2: 1275.24 Hz
# --------------------
# phoneme: ɐ
# 구간 8.46-8.53초의 평균 포먼트 값:
# F1: 834.24 Hz
# F2: 1137.57 Hz
# --------------------
# phoneme: o
# 구간 8.71-8.84초의 평균 포먼트 값:
# F1: 621.01 Hz
# F2: 2065.56 Hz
# --------------------
# phoneme: uː
# 구간 10.95-11.12초의 평균 포먼트 값:
# F1: 695.13 Hz
# F2: 1663.98 Hz
# --------------------
# phoneme: ɐ
# 구간 11.21-11.44초의 평균 포먼트 값:
# F1: 833.81 Hz
# F2: 1216.54 Hz
# --------------------
# phoneme: i
# 구간 13.12-13.16초의 평균 포먼트 값:
# F1: 613.15 Hz
# F2: 1981.20 Hz
# --------------------
# phoneme: o
# 구간 13.39-13.47초의 평균 포먼트 값:
# F1: 598.02 Hz
# F2: 2001.43 Hz
# --------------------
# phoneme: ɛː
# 구간 15.27-15.34초의 평균 포먼트 값:
# F1: 506.20 Hz
# F2: 1711.14 Hz
# --------------------
# phoneme: u
# 구간 15.40-15.46초의 평균 포먼트 값:
# F1: 638.55 Hz
# F2: 1310.73 Hz
# --------------------
# phoneme: ɐ
# 구간 17.31-17.35초의 평균 포먼트 값:
# F1: 826.42 Hz
# F2: 1593.02 Hz
# --------------------
# phoneme: ɐ
# 구간 17.57-17.69초의 평균 포먼트 값:
# F1: 825.72 Hz
# F2: 1453.75 Hz
# --------------------
# phoneme: ɛː
# 구간 19.55-19.59초의 평균 포먼트 값:
# F1: 457.92 Hz
# F2: 1994.95 Hz
# --------------------
# phoneme: ɛː
# 구간 19.79-20.02초의 평균 포먼트 값:
# F1: 392.86 Hz
# F2: 1915.62 Hz
# --------------------
# phoneme: ɛː
# 구간 21.67-21.72초의 평균 포먼트 값:
# F1: 417.48 Hz
# F2: 1777.98 Hz
# --------------------
# phoneme: i
# 구간 21.93-22.01초의 평균 포먼트 값:
# F1: 1628.65 Hz
# F2: 2671.42 Hz
# --------------------
# phoneme: o
# 구간 23.74-23.81초의 평균 포먼트 값:
# F1: 484.04 Hz
# F2: 2224.99 Hz
# --------------------
# phoneme: i
# 구간 24.03-24.26초의 평균 포먼트 값:
# F1: 1183.45 Hz
# F2: 2592.74 Hz
# --------------------
# phoneme: oː
# 구간 26.46-26.58초의 평균 포먼트 값:
# F1: 585.18 Hz
# F2: 2141.10 Hz
# --------------------
# phoneme: o
# 구간 26.64-26.85초의 평균 포먼트 값:
# F1: 578.84 Hz
# F2: 2234.43 Hz
# --------------------
# phoneme: ɛː
# 구간 28.58-28.62초의 평균 포먼트 값:
# F1: 550.87 Hz
# F2: 1822.46 Hz
# --------------------
# phoneme: u
# 구간 28.91-28.99초의 평균 포먼트 값:
# F1: 1104.59 Hz
# F2: 2129.81 Hz
# --------------------
# phoneme: ɛː
# 구간 30.67-30.75초의 평균 포먼트 값:
# F1: 459.90 Hz
# F2: 1887.08 Hz
# --------------------
# phoneme: o
# 구간 30.93-31.20초의 평균 포먼트 값:
# F1: 444.79 Hz
# F2: 2057.81 Hz
# --------------------
# phoneme: ɛː
# 구간 32.83-32.88초의 평균 포먼트 값:
# F1: 613.70 Hz
# F2: 1889.52 Hz
# --------------------
# phoneme: ɐ
# 구간 33.07-33.15초의 평균 포먼트 값:
# F1: 849.57 Hz
# F2: 1243.87 Hz
# --------------------
# phoneme: ɛː
# 구간 34.91-35.03초의 평균 포먼트 값:
# F1: 471.04 Hz
# F2: 1779.81 Hz
# --------------------
# phoneme: o
# 구간 35.10-35.23초의 평균 포먼트 값:
# F1: 523.15 Hz
# F2: 2125.71 Hz
# --------------------
# phoneme: u
# 구간 36.79-36.82초의 평균 포먼트 값:
# F1: 557.37 Hz
# F2: 1864.35 Hz
# --------------------
# phoneme: ɐ
# 구간 37.02-37.12초의 평균 포먼트 값:
# F1: 699.44 Hz
# F2: 1258.76 Hz
# --------------------
# phoneme: iː
# 구간 38.68-38.77초의 평균 포먼트 값:
# F1: 1742.83 Hz
# F2: 3001.26 Hz
# --------------------
# phoneme: ɛː
# 구간 38.84-39.06초의 평균 포먼트 값:
# F1: 436.52 Hz
# F2: 1984.04 Hz
# --------------------
# phoneme: i
# 구간 40.37-40.44초의 평균 포먼트 값:
# F1: 253.29 Hz
# F2: 2047.87 Hz
# --------------------
# phoneme: ɐ
# 구간 40.65-40.86초의 평균 포먼트 값:
# F1: 893.67 Hz
# F2: 1555.26 Hz
# --------------------
# phoneme: ɛː
# 구간 42.31-42.35초의 평균 포먼트 값:
# F1: 350.63 Hz
# F2: 1895.86 Hz
# --------------------
# phoneme: ɛː
# 구간 42.59-42.83초의 평균 포먼트 값:
# F1: 467.20 Hz
# F2: 1908.21 Hz
# --------------------
# phoneme: u
# 구간 44.37-44.48초의 평균 포먼트 값:
# F1: 511.19 Hz
# F2: 2142.90 Hz
# --------------------
# phoneme: o
# 구간 44.56-44.65초의 평균 포먼트 값:
# F1: 656.55 Hz
# F2: 2044.04 Hz
# --------------------
# phoneme: ɐ
# 구간 46.20-46.23초의 평균 포먼트 값:
# F1: 924.16 Hz
# F2: 2012.51 Hz
# --------------------
# phoneme: u
# 구간 46.42-46.66초의 평균 포먼트 값:
# F1: 552.78 Hz
# F2: 1707.46 Hz
# --------------------
# phoneme: ɛː
# 구간 48.16-48.29초의 평균 포먼트 값:
# F1: 386.67 Hz
# F2: 1793.86 Hz
# --------------------
# phoneme: ɐ
# 구간 48.41-48.62초의 평균 포먼트 값:
# F1: 859.24 Hz
# F2: 1248.53 Hz
# --------------------
# phoneme: o
# 구간 50.33-50.46초의 평균 포먼트 값:
# F1: 525.24 Hz
# F2: 1694.52 Hz
# --------------------
# phoneme: ɐ
# 구간 50.70-50.76초의 평균 포먼트 값:
# F1: 914.37 Hz
# F2: 2025.87 Hz
# --------------------
# phoneme: oː
# 구간 52.01-52.11초의 평균 포먼트 값:
# F1: 512.83 Hz
# F2: 1682.41 Hz
# --------------------
# phoneme: u
# 구간 52.16-52.29초의 평균 포먼트 값:
# F1: 596.35 Hz
# F2: 1456.44 Hz
# --------------------
# phoneme: ɐ
# 구간 53.98-54.07초의 평균 포먼트 값:
# F1: 766.14 Hz
# F2: 1447.25 Hz
# --------------------
# phoneme: i
# 구간 54.26-54.49초의 평균 포먼트 값:
# F1: 598.24 Hz
# F2: 2323.53 Hz
# --------------------
# phoneme: ɐ
# 구간 55.87-56.02초의 평균 포먼트 값:
# F1: 981.34 Hz
# F2: 1782.38 Hz
# --------------------
# phoneme: ɛː
# 구간 56.09-56.36초의 평균 포먼트 값:
# F1: 345.10 Hz
# F2: 2028.84 Hz
# --------------------
# phoneme: o
# 구간 57.90-57.98초의 평균 포먼트 값:
# F1: 690.20 Hz
# F2: 1739.17 Hz
# --------------------
# phoneme: i
# 구간 58.21-58.31초의 평균 포먼트 값:
# F1: 555.09 Hz
# F2: 2204.04 Hz
# --------------------
# phoneme: ɐ
# 구간 59.77-59.92초의 평균 포먼트 값:
# F1: 946.93 Hz
# F2: 1360.52 Hz
# --------------------
# phoneme: u
# 구간 59.99-60.06초의 평균 포먼트 값:
# F1: 615.46 Hz
# F2: 1035.95 Hz
# --------------------
# phoneme: i
# 구간 61.67-61.80초의 평균 포먼트 값:
# F1: 550.30 Hz
# F2: 2180.73 Hz
# --------------------
# phoneme: o
# 구간 61.98-62.13초의 평균 포먼트 값:
# F1: 580.58 Hz
# F2: 2226.04 Hz
# --------------------
# phoneme: i
# 구간 63.46-63.61초의 평균 포먼트 값:
# F1: 257.38 Hz
# F2: 2028.23 Hz
# --------------------
# phoneme: i
# 구간 63.67-63.97초의 평균 포먼트 값:
# F1: 303.60 Hz
# F2: 2108.56 Hz
# --------------------
# phoneme: oː
# 구간 65.32-65.36초의 평균 포먼트 값:
# F1: 590.63 Hz
# F2: 1857.57 Hz
# --------------------
# phoneme: u
# 구간 65.59-65.83초의 평균 포먼트 값:
# F1: 530.62 Hz
# F2: 2407.15 Hz
# --------------------
# phoneme: u
# 구간 67.40-67.48초의 평균 포먼트 값:
# F1: 720.78 Hz
# F2: 1214.36 Hz
# --------------------
# phoneme: i
# 구간 67.71-67.98초의 평균 포먼트 값:
# F1: 337.82 Hz
# F2: 2054.49 Hz
# --------------------
# phoneme: u
# 구간 69.35-69.60초의 평균 포먼트 값:
# F1: 579.35 Hz
# F2: 1725.19 Hz
# --------------------
# phoneme: u
# 구간 69.60-69.66초의 평균 포먼트 값:
# F1: 507.91 Hz
# F2: 1046.66 Hz
# --------------------
# phoneme: ɐ
# 구간 71.34-71.40초의 평균 포먼트 값:
# F1: 781.55 Hz
# F2: 1389.43 Hz
# --------------------
# phoneme: ɐ
# 구간 71.66-71.85초의 평균 포먼트 값:
# F1: 879.97 Hz
# F2: 1218.25 Hz
# --------------------
# phoneme: o
# 구간 73.23-73.29초의 평균 포먼트 값:
# F1: 543.84 Hz
# F2: 1740.58 Hz
# --------------------
# phoneme: ɛː
# 구간 73.52-73.67초의 평균 포먼트 값:
# F1: 447.44 Hz
# F2: 1873.49 Hz
# --------------------
# phoneme: u
# 구간 75.09-75.13초의 평균 포먼트 값:
# F1: 676.30 Hz
# F2: 1609.45 Hz
# --------------------
# phoneme: o
# 구간 75.37-75.53초의 평균 포먼트 값:
# F1: 471.30 Hz
# F2: 1892.23 Hz
# --------------------
# phoneme: ɐ
# 구간 76.89-76.94초의 평균 포먼트 값:
# F1: 690.33 Hz
# F2: 1475.78 Hz
# --------------------
# phoneme: ɛː
# 구간 77.14-77.23초의 평균 포먼트 값:
# F1: 423.17 Hz
# F2: 1941.63 Hz
# --------------------
# phoneme: u
# 구간 78.62-78.71초의 평균 포먼트 값:
# F1: 870.08 Hz
# F2: 1921.90 Hz
# --------------------
# phoneme: u
# 구간 78.76-78.87초의 평균 포먼트 값:
# F1: 652.76 Hz
# F2: 2034.04 Hz
# --------------------
# phoneme: i
# 구간 80.36-80.42초의 평균 포먼트 값:
# F1: 214.91 Hz
# F2: 2008.50 Hz
# --------------------
# phoneme: u
# 구간 80.65-80.75초의 평균 포먼트 값:
# F1: 775.19 Hz
# F2: 1835.63 Hz
# --------------------
# phoneme: o
# 구간 82.18-82.27초의 평균 포먼트 값:
# F1: 467.52 Hz
# F2: 1315.10 Hz
# --------------------
# phoneme: ɛː
# 구간 82.47-82.69초의 평균 포먼트 값:
# F1: 427.92 Hz
# F2: 1999.83 Hz
# --------------------
# phoneme: i
# 구간 84.00-84.07초의 평균 포먼트 값:
# F1: 353.17 Hz
# F2: 2091.03 Hz
# --------------------
# phoneme: i
# 구간 84.23-84.34초의 평균 포먼트 값:
# F1: 366.36 Hz
# F2: 2157.37 Hz
# --------------------
# phoneme: i
# 구간 86.05-86.09초의 평균 포먼트 값:
# F1: 689.11 Hz
# F2: 2173.07 Hz
# --------------------
# phoneme: u
# 구간 86.15-86.25초의 평균 포먼트 값:
# F1: 585.50 Hz
# F2: 1373.39 Hz
# --------------------
# phoneme: u
# 구간 87.56-87.59초의 평균 포먼트 값:
# F1: 467.77 Hz
# F2: 1920.38 Hz
# --------------------
# phoneme: ɛː
# 구간 87.76-87.99초의 평균 포먼트 값:
# F1: 526.95 Hz
# F2: 2092.08 Hz
# --------------------
# phoneme: ɐ
# 구간 89.45-89.48초의 평균 포먼트 값:
# F1: 919.14 Hz
# F2: 1238.44 Hz
# --------------------
# phoneme: o
# 구간 89.70-89.76초의 평균 포먼트 값:
# F1: 586.49 Hz
# F2: 2036.27 Hz
# --------------------
# phoneme: u
# 구간 91.33-91.47초의 평균 포먼트 값:
# F1: 742.22 Hz
# F2: 2036.95 Hz
# --------------------
# phoneme: i
# 구간 91.55-91.65초의 평균 포먼트 값:
# F1: 760.92 Hz
# F2: 2386.99 Hz
# --------------------
# phoneme: o
# 구간 93.12-93.32초의 평균 포먼트 값:
# F1: 530.25 Hz
# F2: 1640.56 Hz
# --------------------
# phoneme: ɐ
# 구간 93.32-93.42초의 평균 포먼트 값:
# F1: 894.97 Hz
# F2: 1226.35 Hz
# --------------------
# phoneme: u
# 구간 94.89-94.93초의 평균 포먼트 값:
# F1: 575.24 Hz
# F2: 1882.76 Hz
# --------------------
# phoneme: ɛː
# 구간 95.20-95.28초의 평균 포먼트 값:
# F1: 451.89 Hz
# F2: 1899.78 Hz
# --------------------
# phoneme: ɐ
# 구간 96.86-96.90초의 평균 포먼트 값:
# F1: 802.97 Hz
# F2: 1206.85 Hz
# --------------------
# phoneme: i
# 구간 97.13-97.36초의 평균 포먼트 값:
# F1: 599.70 Hz
# F2: 2403.88 Hz
# --------------------
# phoneme: ɛː
# 구간 98.72-98.85초의 평균 포먼트 값:
# F1: 400.70 Hz
# F2: 1864.23 Hz
# --------------------
# phoneme: i
# 구간 98.95-99.03초의 평균 포먼트 값:
# F1: 321.43 Hz
# F2: 2113.46 Hz
# --------------------
# phoneme: o
# 구간 100.74-100.77초의 평균 포먼트 값:
# F1: 467.28 Hz
# F2: 1368.87 Hz
# --------------------
# phoneme: o
# 구간 100.98-101.04초의 평균 포먼트 값:
# F1: 517.58 Hz
# F2: 1796.91 Hz
# --------------------
# phoneme: i
# 구간 103.04-103.10초의 평균 포먼트 값:
# F1: 205.23 Hz
# F2: 2033.82 Hz
# --------------------
# phoneme: ɐ
# 구간 103.28-103.47초의 평균 포먼트 값:
# F1: 767.27 Hz
# F2: 1382.14 Hz
# --------------------
# phoneme: i
# 구간 105.07-105.10초의 평균 포먼트 값:
# F1: 449.66 Hz
# F2: 1929.32 Hz
# --------------------
# phoneme: o
# 구간 105.34-105.43초의 평균 포먼트 값:
# F1: 558.05 Hz
# F2: 1898.11 Hz
# --------------------
# phoneme: ɐ
# 구간 107.16-107.19초의 평균 포먼트 값:
# F1: 598.73 Hz
# F2: 1326.83 Hz
# --------------------
# phoneme: i
# 구간 107.43-107.63초의 평균 포먼트 값:
# F1: 504.11 Hz
# F2: 2393.11 Hz
# --------------------
# phoneme: u
# 구간 109.23-109.26초의 평균 포먼트 값:
# F1: 459.88 Hz
# F2: 856.72 Hz
# --------------------
# phoneme: u
# 구간 109.26-109.56초의 평균 포먼트 값:
# F1: 480.66 Hz
# F2: 995.42 Hz
# --------------------
# phoneme: ɛː
# 구간 111.19-111.22초의 평균 포먼트 값:
# F1: 371.89 Hz
# F2: 1803.28 Hz
# --------------------
# phoneme: i
# 구간 111.44-111.52초의 평균 포먼트 값:
# F1: 567.23 Hz
# F2: 2130.13 Hz
# --------------------
# phoneme: u
# 구간 113.12-113.15초의 평균 포먼트 값:
# F1: 672.05 Hz
# F2: 2096.98 Hz
# --------------------
# phoneme: ɐ
# 구간 113.32-113.42초의 평균 포먼트 값:
# F1: 693.77 Hz
# F2: 1291.70 Hz
# --------------------
# phoneme: u
# 구간 115.01-115.14초의 평균 포먼트 값:
# F1: 959.91 Hz
# F2: 2072.67 Hz
# --------------------
# phoneme: i
# 구간 115.22-115.31초의 평균 포먼트 값:
# F1: 309.65 Hz
# F2: 1919.35 Hz
# --------------------
# phoneme: ɛː
# 구간 117.04-117.11초의 평균 포먼트 값:
# F1: 461.87 Hz
# F2: 2015.76 Hz
# --------------------
# phoneme: ɛː
# 구간 117.31-117.52초의 평균 포먼트 값:
# F1: 394.42 Hz
# F2: 1912.33 Hz
# --------------------
# phoneme: u
# 구간 119.06-119.25초의 평균 포먼트 값:
# F1: 562.13 Hz
# F2: 1744.69 Hz
# --------------------
# phoneme: o
# 구간 119.34-119.40초의 평균 포먼트 값:
# F1: 705.42 Hz
# F2: 1809.55 Hz
# --------------------
# phoneme: ɐ
# 구간 121.09-121.22초의 평균 포먼트 값:
# F1: 920.89 Hz
# F2: 1531.50 Hz
# --------------------
# phoneme: u
# 구간 121.28-121.35초의 평균 포먼트 값:
# F1: 610.24 Hz
# F2: 1355.50 Hz
# --------------------
# phoneme: o
# 구간 123.02-123.10초의 평균 포먼트 값:
# F1: 534.72 Hz
# F2: 2074.71 Hz
# --------------------
# phoneme: ɐ
# 구간 123.34-123.43초의 평균 포먼트 값:
# F1: 899.83 Hz
# F2: 1798.92 Hz
# --------------------
# phoneme: ɐ
# 구간 124.97-125.01초의 평균 포먼트 값:
# F1: 755.55 Hz
# F2: 1688.08 Hz
# --------------------
# phoneme: ɐ
# 구간 125.29-125.34초의 평균 포먼트 값:
# F1: 926.29 Hz
# F2: 1221.67 Hz
# --------------------
# phoneme: i
# 구간 127.03-127.07초의 평균 포먼트 값:
# F1: 232.00 Hz
# F2: 2033.05 Hz
# --------------------
# phoneme: u
# 구간 127.37-127.44초의 평균 포먼트 값:
# F1: 705.01 Hz
# F2: 1463.25 Hz
# --------------------
# phoneme: u
# 구간 129.15-129.26초의 평균 포먼트 값:
# F1: 684.70 Hz
# F2: 1825.08 Hz
# --------------------
# phoneme: u
# 구간 129.31-129.38초의 평균 포먼트 값:
# F1: 567.79 Hz
# F2: 1734.32 Hz
# --------------------
# phoneme: ɛː
# 구간 131.01-131.04초의 평균 포먼트 값:
# F1: 362.07 Hz
# F2: 1939.12 Hz
# --------------------
# phoneme: ɛː
# 구간 131.31-131.52초의 평균 포먼트 값:
# F1: 908.96 Hz
# F2: 2281.41 Hz
# --------------------
# phoneme: u
# 구간 133.13-133.17초의 평균 포먼트 값:
# F1: 747.03 Hz
# F2: 1889.30 Hz
# --------------------
# phoneme: ɛː
# 구간 133.42-133.50초의 평균 포먼트 값:
# F1: 530.96 Hz
# F2: 1938.90 Hz
# --------------------
# phoneme: ɐ
# 구간 135.01-135.07초의 평균 포먼트 값:
# F1: 691.29 Hz
# F2: 1348.74 Hz
# --------------------
# phoneme: ɐ
# 구간 135.33-135.48초의 평균 포먼트 값:
# F1: 819.22 Hz
# F2: 1063.49 Hz
# --------------------
# phoneme: ɐ
# 구간 136.76-136.86초의 평균 포먼트 값:
# F1: 745.28 Hz
# F2: 1376.80 Hz
# --------------------
# phoneme: i
# 구간 137.02-137.26초의 평균 포먼트 값:
# F1: 463.06 Hz
# F2: 2244.07 Hz
# --------------------
# phoneme: i
# 구간 138.70-138.74초의 평균 포먼트 값:
# F1: 327.48 Hz
# F2: 1820.73 Hz
# --------------------
# phoneme: ɛː
# 구간 138.98-139.06초의 평균 포먼트 값:
# F1: 452.90 Hz
# F2: 1956.55 Hz
# --------------------
# phoneme: o
# 구간 140.70-140.73초의 평균 포먼트 값:
# F1: 580.04 Hz
# F2: 1864.26 Hz
# --------------------
# phoneme: o
# 구간 140.98-141.02초의 평균 포먼트 값:
# F1: 584.41 Hz
# F2: 2126.54 Hz
# --------------------
# phoneme: o
# 구간 142.66-142.75초의 평균 포먼트 값:
# F1: 499.65 Hz
# F2: 1683.16 Hz
# --------------------
# phoneme: i
# 구간 143.00-143.09초의 평균 포먼트 값:
# F1: 364.67 Hz
# F2: 2181.57 Hz
# --------------------
# phoneme: ɛː
# 구간 144.72-144.80초의 평균 포먼트 값:
# F1: 452.26 Hz
# F2: 1715.34 Hz
# --------------------
# phoneme: o
# 구간 144.91-145.01초의 평균 포먼트 값:
# F1: 455.40 Hz
# F2: 1819.11 Hz
# --------------------
# phoneme: i
# 구간 146.78-146.82초의 평균 포먼트 값:
# F1: 276.98 Hz
# F2: 1992.24 Hz
# --------------------
# phoneme: o
# 구간 147.04-147.12초의 평균 포먼트 값:
# F1: 516.83 Hz
# F2: 2130.85 Hz
# --------------------
# phoneme: oː
# 구간 148.72-148.77초의 평균 포먼트 값:
# F1: 518.06 Hz
# F2: 1908.54 Hz
# --------------------
# phoneme: u
# 구간 148.85-148.94초의 평균 포먼트 값:
# F1: 526.59 Hz
# F2: 1299.39 Hz
# --------------------
# phoneme: ɐ
# 구간 150.71-150.75초의 평균 포먼트 값:
# F1: 964.29 Hz
# F2: 1700.28 Hz
# --------------------
# phoneme: o
# 구간 150.90-150.99초의 평균 포먼트 값:
# F1: 549.14 Hz
# F2: 1869.18 Hz
# --------------------
# phoneme: o
# 구간 153.38-153.54초의 평균 포먼트 값:
# F1: 660.61 Hz
# F2: 2298.50 Hz
# --------------------
# phoneme: ɐ
# 구간 153.54-153.60초의 평균 포먼트 값:
# F1: 721.34 Hz
# F2: 1860.42 Hz
# --------------------
# phoneme: i
# 구간 155.40-155.45초의 평균 포먼트 값:
# F1: 548.05 Hz
# F2: 2235.86 Hz
# --------------------
# phoneme: u
# 구간 155.51-155.61초의 평균 포먼트 값:
# F1: 650.35 Hz
# F2: 1350.87 Hz
# --------------------
# phoneme: ɐ
# 구간 157.17-157.23초의 평균 포먼트 값:
# F1: 814.47 Hz
# F2: 1091.76 Hz
# --------------------
# phoneme: u
# 구간 157.47-157.63초의 평균 포먼트 값:
# F1: 543.66 Hz
# F2: 2229.53 Hz
# --------------------
# phoneme: u
# 구간 159.13-159.16초의 평균 포먼트 값:
# F1: 697.94 Hz
# F2: 1591.02 Hz
# --------------------
# phoneme: i
# 구간 159.41-159.60초의 평균 포먼트 값:
# F1: 434.70 Hz
# F2: 2374.67 Hz
# --------------------
# phoneme: o
# 구간 161.09-161.16초의 평균 포먼트 값:
# F1: 473.26 Hz
# F2: 2030.10 Hz
# --------------------
# phoneme: i
# 구간 161.38-161.55초의 평균 포먼트 값:
# F1: 593.58 Hz
# F2: 2400.68 Hz
# --------------------
# phoneme: ɛː
# 구간 163.07-163.13초의 평균 포먼트 값:
# F1: 492.07 Hz
# F2: 1799.31 Hz
# --------------------
# phoneme: u
# 구간 163.33-163.39초의 평균 포먼트 값:
# F1: 698.61 Hz
# F2: 1606.16 Hz
# --------------------
# phoneme: i
# 구간 165.04-165.17초의 평균 포먼트 값:
# F1: 259.71 Hz
# F2: 2048.77 Hz
# --------------------
# phoneme: i
# 구간 165.28-165.52초의 평균 포먼트 값:
# F1: 347.10 Hz
# F2: 2250.13 Hz
# --------------------
# phoneme: o
# 구간 166.95-166.99초의 평균 포먼트 값:
# F1: 556.94 Hz
# F2: 2070.70 Hz
# --------------------
# phoneme: ɛː
# 구간 167.24-167.45초의 평균 포먼트 값:
# F1: 530.69 Hz
# F2: 2020.64 Hz
# --------------------
# phoneme: ɐ
# 구간 169.07-169.10초의 평균 포먼트 값:
# F1: 392.40 Hz
# F2: 1628.28 Hz
# --------------------
# phoneme: o
# 구간 169.26-169.31초의 평균 포먼트 값:
# F1: 582.51 Hz
# F2: 1739.60 Hz
# --------------------
# phoneme: ɐ
# 구간 171.06-171.09초의 평균 포먼트 값:
# F1: 425.20 Hz
# F2: 2033.77 Hz
# --------------------
# phoneme: ɛː
# 구간 171.09-171.23초의 평균 포먼트 값:
# F1: 418.83 Hz
# F2: 2081.77 Hz
# --------------------
# phoneme: oː
# 구간 172.94-172.97초의 평균 포먼트 값:
# F1: 579.52 Hz
# F2: 1830.10 Hz
# --------------------
# phoneme: u
# 구간 173.15-173.35초의 평균 포먼트 값:
# F1: 465.13 Hz
# F2: 2121.18 Hz
# --------------------
# phoneme: ɐ
# 구간 175.00-175.06초의 평균 포먼트 값:
# F1: 618.56 Hz
# F2: 1472.97 Hz
# --------------------
# phoneme: ɛː
# 구간 175.27-175.38초의 평균 포먼트 값:
# F1: 418.48 Hz
# F2: 1945.02 Hz
# --------------------
# phoneme: ɛː
# 구간 177.18-177.28초의 평균 포먼트 값:
# F1: 411.40 Hz
# F2: 1868.10 Hz
# --------------------
# phoneme: ɐ
# 구간 177.38-177.56초의 평균 포먼트 값:
# F1: 890.17 Hz
# F2: 1682.57 Hz
# --------------------
# phoneme: ɛː
# 구간 178.91-179.04초의 평균 포먼트 값:
# F1: 761.47 Hz
# F2: 2105.15 Hz
# --------------------
# phoneme: ɐ
# 구간 179.13-179.20초의 평균 포먼트 값:
# F1: 766.42 Hz
# F2: 1120.97 Hz
# --------------------
# phoneme: uː
# 구간 180.80-180.92초의 평균 포먼트 값:
# F1: 571.37 Hz
# F2: 978.95 Hz
# --------------------
# phoneme: ɐ
# 구간 181.00-181.23초의 평균 포먼트 값:
# F1: 899.43 Hz
# F2: 2216.47 Hz
# --------------------
# phoneme: i
# 구간 182.65-182.68초의 평균 포먼트 값:
# F1: 310.91 Hz
# F2: 1856.69 Hz
# --------------------
# phoneme: ɐ
# 구간 182.93-183.14초의 평균 포먼트 값:
# F1: 842.09 Hz
# F2: 1599.57 Hz
# --------------------
# phoneme: oː
# 구간 184.55-184.63초의 평균 포먼트 값:
# F1: 802.87 Hz
# F2: 2380.74 Hz
# --------------------
# phoneme: o
# 구간 184.69-184.89초의 평균 포먼트 값:
# F1: 518.97 Hz
# F2: 1946.97 Hz
# --------------------
# phoneme: u
# 구간 186.50-186.54초의 평균 포먼트 값:
# F1: 1209.70 Hz
# F2: 2063.80 Hz
# --------------------
# phoneme: o
# 구간 186.72-186.89초의 평균 포먼트 값:
# F1: 450.69 Hz
# F2: 1923.43 Hz
# --------------------
# phoneme: i
# 구간 188.12-188.18초의 평균 포먼트 값:
# F1: 313.66 Hz
# F2: 2162.17 Hz
# --------------------
# phoneme: i
# 구간 188.33-188.41초의 평균 포먼트 값:
# F1: 329.67 Hz
# F2: 2172.68 Hz
# --------------------
# phoneme: u
# 구간 189.88-189.93초의 평균 포먼트 값:
# F1: 674.16 Hz
# F2: 1580.35 Hz
# --------------------
# phoneme: ɛː
# 구간 190.18-190.39초의 평균 포먼트 값:
# F1: 565.69 Hz
# F2: 2112.06 Hz
# --------------------
# phoneme: ɛː
# 구간 191.85-191.98초의 평균 포먼트 값:
# F1: 425.61 Hz
# F2: 1853.91 Hz
# --------------------
# phoneme: i
# 구간 192.08-192.16초의 평균 포먼트 값:
# F1: 395.44 Hz
# F2: 2141.90 Hz
# --------------------
# phoneme: o
# 구간 193.85-193.93초의 평균 포먼트 값:
# F1: 694.35 Hz
# F2: 1503.67 Hz
# --------------------
# phoneme: ɛː
# 구간 194.13-194.36초의 평균 포먼트 값:
# F1: 415.74 Hz
# F2: 2075.73 Hz
# --------------------
# phoneme: ɛː
# 구간 195.69-195.81초의 평균 포먼트 값:
# F1: 454.14 Hz
# F2: 1890.64 Hz
# --------------------
# phoneme: o
# 구간 195.88-196.14초의 평균 포먼트 값:
# F1: 479.57 Hz
# F2: 2050.17 Hz
# --------------------
# phoneme: ɛː
# 구간 197.40-197.49초의 평균 포먼트 값:
# F1: 535.19 Hz
# F2: 1831.89 Hz
# --------------------
# phoneme: u
# 구간 197.58-197.61초의 평균 포먼트 값:
# F1: 728.68 Hz
# F2: 1366.98 Hz
# --------------------
# phoneme: iː
# 구간 199.23-199.30초의 평균 포먼트 값:
# F1: 1477.58 Hz
# F2: 2874.29 Hz
# --------------------
# phoneme: ɛː
# 구간 199.37-199.58초의 평균 포먼트 값:
# F1: 437.39 Hz
# F2: 1982.98 Hz
# --------------------
# phoneme: ɐ
# 구간 201.09-201.15초의 평균 포먼트 값:
# F1: 815.97 Hz
# F2: 1116.82 Hz
# --------------------
# phoneme: o
# 구간 201.30-201.43초의 평균 포먼트 값:
# F1: 649.01 Hz
# F2: 1707.47 Hz
# --------------------
# phoneme: ɛː
# 구간 202.93-203.00초의 평균 포먼트 값:
# F1: 375.28 Hz
# F2: 1902.08 Hz
# --------------------
# phoneme: ɛː
# 구간 203.17-203.42초의 평균 포먼트 값:
# F1: 405.06 Hz
# F2: 1941.24 Hz
# --------------------
# phoneme: ɐ
# 구간 204.93-204.99초의 평균 포먼트 값:
# F1: 720.18 Hz
# F2: 1386.62 Hz
# --------------------
# phoneme: ɐ
# 구간 205.22-205.42초의 평균 포먼트 값:
# F1: 864.68 Hz
# F2: 1328.28 Hz
# --------------------
# phoneme: i
# 구간 206.86-206.93초의 평균 포먼트 값:
# F1: 1769.76 Hz
# F2: 2728.33 Hz
# --------------------
# phoneme: u
# 구간 207.00-207.10초의 평균 포먼트 값:
# F1: 622.09 Hz
# F2: 1296.89 Hz
# --------------------
# phoneme: u
# 구간 208.84-208.94초의 평균 포먼트 값:
# F1: 636.53 Hz
# F2: 1865.27 Hz
# --------------------
# phoneme: i
# 구간 209.01-209.10초의 평균 포먼트 값:
# F1: 683.34 Hz
# F2: 2232.78 Hz
# --------------------
# phoneme: ɛː
# 구간 210.59-210.67초의 평균 포먼트 값:
# F1: 414.91 Hz
# F2: 1856.85 Hz
# --------------------
# phoneme: i
# 구간 210.74-210.82초의 평균 포먼트 값:
# F1: 300.12 Hz
# F2: 2068.68 Hz
# --------------------
# phoneme: ɛː
# 구간 212.30-212.41초의 평균 포먼트 값:
# F1: 479.80 Hz
# F2: 1864.88 Hz
# --------------------
# phoneme: o
# 구간 212.47-212.74초의 평균 포먼트 값:
# F1: 537.56 Hz
# F2: 2004.68 Hz
# --------------------
# phoneme: ɐ
# 구간 214.27-214.34초의 평균 포먼트 값:
# F1: 952.04 Hz
# F2: 1476.46 Hz
# --------------------
# phoneme: o
# 구간 214.53-214.62초의 평균 포먼트 값:
# F1: 567.34 Hz
# F2: 1749.86 Hz
# --------------------
# phoneme: o
# 구간 216.12-216.15초의 평균 포먼트 값:
# F1: 469.05 Hz
# F2: 2086.87 Hz
# --------------------
# phoneme: ɛː
# 구간 216.35-216.54초의 평균 포먼트 값:
# F1: 433.25 Hz
# F2: 1993.83 Hz
# --------------------
# phoneme: ɐ
# 구간 218.26-218.30초의 평균 포먼트 값:
# F1: 904.63 Hz
# F2: 1009.76 Hz
# --------------------
# phoneme: u
# 구간 218.57-218.65초의 평균 포먼트 값:
# F1: 514.55 Hz
# F2: 2249.71 Hz
# --------------------
# phoneme: u
# 구간 219.91-219.99초의 평균 포먼트 값:
# F1: 465.77 Hz
# F2: 1440.43 Hz
# --------------------
# phoneme: u
# 구간 220.05-220.11초의 평균 포먼트 값:
# F1: 600.17 Hz
# F2: 1979.13 Hz
# --------------------
# phoneme: ɐ
# 구간 221.72-221.78초의 평균 포먼트 값:
# F1: 774.25 Hz
# F2: 1518.04 Hz
# --------------------
# phoneme: i
# 구간 221.94-222.14초의 평균 포먼트 값:
# F1: 352.56 Hz
# F2: 2169.63 Hz
# --------------------
# phoneme: ɛː
# 구간 223.67-223.76초의 평균 포먼트 값:
# F1: 452.73 Hz
# F2: 1737.16 Hz
# --------------------
# phoneme: o
# 구간 223.85-223.96초의 평균 포먼트 값:
# F1: 543.06 Hz
# F2: 2073.60 Hz
# --------------------
# phoneme: o
# 구간 225.37-225.44초의 평균 포먼트 값:
# F1: 652.61 Hz
# F2: 1993.80 Hz
# --------------------
# phoneme: i
# 구간 225.63-225.71초의 평균 포먼트 값:
# F1: 477.06 Hz
# F2: 2240.94 Hz
# --------------------
# phoneme: u
# 구간 227.34-227.37초의 평균 포먼트 값:
# F1: 520.27 Hz
# F2: 1939.31 Hz
# --------------------
# phoneme: ɐ
# 구간 227.57-227.67초의 평균 포먼트 값:
# F1: 819.54 Hz
# F2: 1399.54 Hz
# --------------------
# phoneme: oː
# 구간 229.40-229.49초의 평균 포먼트 값:
# F1: 509.61 Hz
# F2: 1115.18 Hz
# --------------------
# phoneme: o
# 구간 229.55-229.76초의 평균 포먼트 값:
# F1: 557.48 Hz
# F2: 2125.12 Hz
# --------------------
# phoneme: i
# 구간 231.37-231.42초의 평균 포먼트 값:
# F1: 346.30 Hz
# F2: 2108.08 Hz
# --------------------
# phoneme: i
# 구간 231.58-231.69초의 평균 포먼트 값:
# F1: 346.63 Hz
# F2: 2178.74 Hz
# --------------------
# phoneme: o
# 구간 233.25-233.28초의 평균 포먼트 값:
# F1: 494.93 Hz
# F2: 1005.24 Hz
# --------------------
# phoneme: ɐ
# 구간 233.54-233.64초의 평균 포먼트 값:
# F1: 973.07 Hz
# F2: 1885.42 Hz
# --------------------
# phoneme: iː
# 구간 235.26-235.37초의 평균 포먼트 값:
# F1: 665.67 Hz
# F2: 2321.06 Hz
# --------------------
# phoneme: ɛː
# 구간 235.45-235.64초의 평균 포먼트 값:
# F1: 462.92 Hz
# F2: 1928.42 Hz
# --------------------
# phoneme: ɛː
# 구간 236.98-237.01초의 평균 포먼트 값:
# F1: 384.02 Hz
# F2: 1789.60 Hz
# --------------------
# phoneme: i
# 구간 237.23-237.27초의 평균 포먼트 값:
# F1: 695.52 Hz
# F2: 2285.91 Hz
# --------------------
# phoneme: ɛː
# 구간 238.74-238.79초의 평균 포먼트 값:
# F1: 387.01 Hz
# F2: 2009.85 Hz
# --------------------
# phoneme: ɛː
# 구간 238.99-239.16초의 평균 포먼트 값:
# F1: 416.91 Hz
# F2: 1908.85 Hz
# --------------------
# phoneme: ɛː
# 구간 240.54-240.59초의 평균 포먼트 값:
# F1: 414.21 Hz
# F2: 1787.23 Hz
# --------------------
# phoneme: ɐ
# 구간 240.78-240.85초의 평균 포먼트 값:
# F1: 878.16 Hz
# F2: 1235.38 Hz
# --------------------
# phoneme: oː
# 구간 242.40-242.47초의 평균 포먼트 값:
# F1: 538.32 Hz
# F2: 1244.77 Hz
# --------------------
# phoneme: u
# 구간 242.54-242.63초의 평균 포먼트 값:
# F1: 546.65 Hz
# F2: 1461.58 Hz
# --------------------
# phoneme: u
# 구간 244.16-244.24초의 평균 포먼트 값:
# F1: 727.85 Hz
# F2: 1863.14 Hz
# --------------------
# phoneme: i
# 구간 244.48-244.69초의 평균 포먼트 값:
# F1: 501.89 Hz
# F2: 2233.99 Hz
# --------------------
# phoneme: o
# 구간 246.10-246.13초의 평균 포먼트 값:
# F1: 593.26 Hz
# F2: 1684.33 Hz
# --------------------
# phoneme: o
# 구간 246.40-246.44초의 평균 포먼트 값:
# F1: 574.85 Hz
# F2: 1517.87 Hz
# --------------------
# phoneme: u
# 구간 247.95-247.99초의 평균 포먼트 값:
# F1: 734.16 Hz
# F2: 1830.82 Hz
# --------------------
# phoneme: o
# 구간 248.22-248.38초의 평균 포먼트 값:
# F1: 460.74 Hz
# F2: 1992.47 Hz
# --------------------
# phoneme: u
# 구간 250.14-250.18초의 평균 포먼트 값:
# F1: 779.19 Hz
# F2: 1632.59 Hz
# --------------------
# phoneme: ɛː
# 구간 250.42-250.60초의 평균 포먼트 값:
# F1: 508.09 Hz
# F2: 2041.39 Hz
# --------------------
# phoneme: ɛː
# 구간 252.48-252.57초의 평균 포먼트 값:
# F1: 407.03 Hz
# F2: 1849.03 Hz
# --------------------
# phoneme: ɐ
# 구간 252.68-252.82초의 평균 포먼트 값:
# F1: 880.94 Hz
# F2: 1349.11 Hz
# --------------------
# phoneme: ɐ
# 구간 254.35-254.42초의 평균 포먼트 값:
# F1: 1031.43 Hz
# F2: 1514.10 Hz
# --------------------
# phoneme: ɛː
# 구간 254.48-254.70초의 평균 포먼트 값:
# F1: 402.19 Hz
# F2: 2074.51 Hz
# --------------------
# phoneme: o
# 구간 256.33-256.38초의 평균 포먼트 값:
# F1: 513.89 Hz
# F2: 2122.02 Hz
# --------------------
# phoneme: i
# 구간 256.59-256.78초의 평균 포먼트 값:
# F1: 736.07 Hz
# F2: 2380.42 Hz
# --------------------
# phoneme: u
# 구간 258.19-258.30초의 평균 포먼트 값:
# F1: 465.54 Hz
# F2: 1241.75 Hz
# --------------------
# phoneme: o
# 구간 258.35-258.47초의 평균 포먼트 값:
# F1: 605.57 Hz
# F2: 1954.57 Hz
# --------------------
# phoneme: uː
# 구간 260.13-260.21초의 평균 포먼트 값:
# F1: 804.09 Hz
# F2: 2278.13 Hz
# --------------------
# phoneme: ɐ
# 구간 260.32-260.53초의 평균 포먼트 값:
# F1: 892.72 Hz
# F2: 1504.65 Hz
# --------------------
# phoneme: i
# 구간 261.98-262.03초의 평균 포먼트 값:
# F1: 303.85 Hz
# F2: 2038.65 Hz
# --------------------
# phoneme: u
# 구간 262.25-262.34초의 평균 포먼트 값:
# F1: 681.39 Hz
# F2: 1637.66 Hz
# --------------------
# phoneme: ɛː
# 구간 264.14-264.18초의 평균 포먼트 값:
# F1: 482.93 Hz
# F2: 1714.04 Hz
# --------------------
# phoneme: u
# 구간 264.42-264.54초의 평균 포먼트 값:
# F1: 584.13 Hz
# F2: 1620.87 Hz
# --------------------
# phoneme: oː
# 구간 266.18-266.21초의 평균 포먼트 값:
# F1: 562.92 Hz
# F2: 1674.48 Hz
# --------------------
# phoneme: u
# 구간 266.45-266.66초의 평균 포먼트 값:
# F1: 497.52 Hz
# F2: 1896.41 Hz
# --------------------
# phoneme: i
# 구간 268.76-268.80초의 평균 포먼트 값:
# F1: 629.56 Hz
# F2: 2155.77 Hz
# --------------------
# phoneme: ɛː
# 구간 268.97-269.08초의 평균 포먼트 값:
# F1: 417.66 Hz
# F2: 1953.73 Hz
# --------------------
# phoneme: ɐ
# 구간 270.66-270.72초의 평균 포먼트 값:
# F1: 933.18 Hz
# F2: 1559.95 Hz
# --------------------
# phoneme: u
# 구간 270.79-270.87초의 평균 포먼트 값:
# F1: 621.38 Hz
# F2: 1696.11 Hz
# --------------------
# phoneme: i
# 구간 272.69-272.73초의 평균 포먼트 값:
# F1: 619.34 Hz
# F2: 2302.61 Hz
# --------------------
# phoneme: o
# 구간 272.90-273.04초의 평균 포먼트 값:
# F1: 504.82 Hz
# F2: 2332.64 Hz
# --------------------
# phoneme: ɐ
# 구간 274.74-274.80초의 평균 포먼트 값:
# F1: 690.62 Hz
# F2: 1431.61 Hz
# --------------------
# phoneme: ɛː
# 구간 275.01-275.09초의 평균 포먼트 값:
# F1: 386.98 Hz
# F2: 1903.05 Hz
# --------------------
# phoneme: o
# 구간 276.78-276.81초의 평균 포먼트 값:
# F1: 877.52 Hz
# F2: 2242.22 Hz
# --------------------
# phoneme: ɐ
# 구간 276.81-276.89초의 평균 포먼트 값:
# F1: 797.09 Hz
# F2: 1900.72 Hz
# --------------------
# phoneme: ɐ
# 구간 278.48-278.51초의 평균 포먼트 값:
# F1: 771.04 Hz
# F2: 1592.98 Hz
# --------------------
# phoneme: ɐ
# 구간 278.73-278.82초의 평균 포먼트 값:
# F1: 918.87 Hz
# F2: 1566.44 Hz
# --------------------
# phoneme: i
# 구간 280.32-280.38초의 평균 포먼트 값:
# F1: 341.67 Hz
# F2: 1907.60 Hz
# --------------------
# phoneme: ɐ
# 구간 280.57-280.74초의 평균 포먼트 값:
# F1: 777.45 Hz
# F2: 1560.73 Hz
# --------------------
# phoneme: i
# 구간 282.03-282.08초의 평균 포먼트 값:
# F1: 321.80 Hz
# F2: 2040.19 Hz
# --------------------
# phoneme: ɐ
# 구간 282.27-282.45초의 평균 포먼트 값:
# F1: 891.28 Hz
# F2: 1405.86 Hz
# --------------------
# phoneme: i
# 구간 283.82-283.98초의 평균 포먼트 값:
# F1: 277.26 Hz
# F2: 2050.81 Hz
# --------------------
# phoneme: i
# 구간 284.04-284.25초의 평균 포먼트 값:
# F1: 298.45 Hz
# F2: 2088.75 Hz
# --------------------
# phoneme: u
# 구간 285.67-285.81초의 평균 포먼트 값:
# F1: 648.71 Hz
# F2: 2584.43 Hz
# --------------------
# phoneme: u
# 구간 285.81-285.98초의 평균 포먼트 값:
# F1: 645.15 Hz
# F2: 2728.06 Hz
# --------------------
# phoneme: ɛː
# 구간 287.49-287.55초의 평균 포먼트 값:
# F1: 533.52 Hz
# F2: 1766.11 Hz
# --------------------
# phoneme: u
# 구간 287.61-287.64초의 평균 포먼트 값:
# F1: 870.91 Hz
# F2: 2129.35 Hz
# --------------------
# phoneme: o
# 구간 289.06-289.14초의 평균 포먼트 값:
# F1: 587.54 Hz
# F2: 1342.91 Hz
# --------------------
# phoneme: ɛː
# 구간 289.34-289.52초의 평균 포먼트 값:
# F1: 409.46 Hz
# F2: 2019.20 Hz
# --------------------
# phoneme: u
# 구간 290.89-290.93초의 평균 포먼트 값:
# F1: 665.08 Hz
# F2: 1900.41 Hz
# --------------------
# phoneme: ɛː
# 구간 291.20-291.32초의 평균 포먼트 값:
# F1: 429.74 Hz
# F2: 1897.46 Hz
# --------------------
# phoneme: i
# 구간 292.80-292.84초의 평균 포먼트 값:
# F1: 815.28 Hz
# F2: 2137.05 Hz
# --------------------
# phoneme: o
# 구간 293.04-293.13초의 평균 포먼트 값:
# F1: 505.13 Hz
# F2: 1105.19 Hz
# --------------------
# phoneme: ɐ
# 구간 294.62-294.68초의 평균 포먼트 값:
# F1: 1057.22 Hz
# F2: 1624.37 Hz
# --------------------
# phoneme: i
# 구간 294.86-295.08초의 평균 포먼트 값:
# F1: 377.41 Hz
# F2: 2338.83 Hz
# --------------------
# total detected phonemes: 300
# 파일 정보:
# 전체 길이: 268.656초
# Tier 목록: ['words', 'phones']
#
# ==================================================
#
# Tier: phones
# ------------------------------
# <class 'list'>
# phoneme: ɛː
# 구간 2.74-2.83초의 평균 포먼트 값:
# F1: 653.62 Hz
# F2: 2034.28 Hz
# --------------------
# phoneme: o
# 구간 2.93-3.25초의 평균 포먼트 값:
# F1: 496.76 Hz
# F2: 2140.94 Hz
# --------------------
# phoneme: ɛː
# 구간 4.77-4.81초의 평균 포먼트 값:
# F1: 477.82 Hz
# F2: 1776.12 Hz
# --------------------
# phoneme: u
# 구간 5.01-5.10초의 평균 포먼트 값:
# F1: 594.25 Hz
# F2: 1684.77 Hz
# --------------------
# phoneme: ɛː
# 구간 6.89-6.98초의 평균 포먼트 값:
# F1: 460.86 Hz
# F2: 1852.95 Hz
# --------------------
# phoneme: ɐ
# 구간 7.11-7.19초의 평균 포먼트 값:
# F1: 831.07 Hz
# F2: 1459.56 Hz
# --------------------
# phoneme: o
# 구간 8.99-9.08초의 평균 포먼트 값:
# F1: 525.34 Hz
# F2: 2071.80 Hz
# --------------------
# phoneme: i
# 구간 9.28-9.46초의 평균 포먼트 값:
# F1: 942.10 Hz
# F2: 2528.48 Hz
# --------------------
# phoneme: oː
# 구간 10.84-10.88초의 평균 포먼트 값:
# F1: 646.24 Hz
# F2: 2014.22 Hz
# --------------------
# phoneme: u
# 구간 11.08-11.29초의 평균 포먼트 값:
# F1: 562.18 Hz
# F2: 2149.19 Hz
# --------------------
# phoneme: i
# 구간 12.77-12.81초의 평균 포먼트 값:
# F1: 497.70 Hz
# F2: 2083.97 Hz
# --------------------
# phoneme: u
# 구간 12.86-12.98초의 평균 포먼트 값:
# F1: 666.05 Hz
# F2: 1442.62 Hz
# --------------------
# phoneme: o
# 구간 14.48-14.54초의 평균 포먼트 값:
# F1: 705.35 Hz
# F2: 1613.88 Hz
# --------------------
# phoneme: ɛː
# 구간 14.69-14.92초의 평균 포먼트 값:
# F1: 407.77 Hz
# F2: 2036.67 Hz
# --------------------
# phoneme: u
# 구간 16.28-16.42초의 평균 포먼트 값:
# F1: 550.59 Hz
# F2: 2169.30 Hz
# --------------------
# phoneme: o
# 구간 16.46-16.55초의 평균 포먼트 값:
# F1: 490.27 Hz
# F2: 1811.47 Hz
# --------------------
# phoneme: u
# 구간 17.93-17.96초의 평균 포먼트 값:
# F1: 541.29 Hz
# F2: 2155.23 Hz
# --------------------
# phoneme: u
# 구간 17.96-18.26초의 평균 포먼트 값:
# F1: 590.48 Hz
# F2: 2002.92 Hz
# --------------------
# phoneme: ɐ
# 구간 19.64-19.72초의 평균 포먼트 값:
# F1: 972.87 Hz
# F2: 1771.48 Hz
# --------------------
# phoneme: u
# 구간 19.78-19.86초의 평균 포먼트 값:
# F1: 679.51 Hz
# F2: 1768.17 Hz
# --------------------
# phoneme: ɛː
# 구간 21.56-21.60초의 평균 포먼트 값:
# F1: 402.44 Hz
# F2: 1944.79 Hz
# --------------------
# phoneme: ɛː
# 구간 21.79-21.99초의 평균 포먼트 값:
# F1: 404.40 Hz
# F2: 1946.39 Hz
# --------------------
# phoneme: u
# 구간 23.38-23.41초의 평균 포먼트 값:
# F1: 755.94 Hz
# F2: 2061.29 Hz
# --------------------
# phoneme: i
# 구간 23.63-23.85초의 평균 포먼트 값:
# F1: 836.40 Hz
# F2: 2396.67 Hz
# --------------------
# phoneme: o
# 구간 25.45-25.48초의 평균 포먼트 값:
# F1: 599.30 Hz
# F2: 1967.34 Hz
# --------------------
# phoneme: o
# 구간 25.68-25.76초의 평균 포먼트 값:
# F1: 622.55 Hz
# F2: 2087.74 Hz
# --------------------
# phoneme: ɐ
# 구간 27.39-27.45초의 평균 포먼트 값:
# F1: 945.56 Hz
# F2: 1266.52 Hz
# --------------------
# phoneme: u
# 구간 27.68-27.87초의 평균 포먼트 값:
# F1: 677.86 Hz
# F2: 2041.73 Hz
# --------------------
# phoneme: u
# 구간 29.36-29.45초의 평균 포먼트 값:
# F1: 1099.36 Hz
# F2: 2248.96 Hz
# --------------------
# phoneme: u
# 구간 29.49-29.56초의 평균 포먼트 값:
# F1: 679.05 Hz
# F2: 1768.17 Hz
# --------------------
# phoneme: i
# 구간 31.09-31.15초의 평균 포먼트 값:
# F1: 318.99 Hz
# F2: 2286.63 Hz
# --------------------
# phoneme: ɐ
# 구간 31.33-31.53초의 평균 포먼트 값:
# F1: 843.70 Hz
# F2: 1565.18 Hz
# --------------------
# phoneme: u
# 구간 32.98-33.02초의 평균 포먼트 값:
# F1: 556.06 Hz
# F2: 1581.15 Hz
# --------------------
# phoneme: o
# 구간 33.23-33.42초의 평균 포먼트 값:
# F1: 425.21 Hz
# F2: 1995.24 Hz
# --------------------
# phoneme: ɐ
# 구간 34.76-34.84초의 평균 포먼트 값:
# F1: 843.50 Hz
# F2: 1589.55 Hz
# --------------------
# phoneme: i
# 구간 35.03-35.25초의 평균 포먼트 값:
# F1: 485.86 Hz
# F2: 2296.13 Hz
# --------------------
# phoneme: ɛː
# 구간 36.68-36.73초의 평균 포먼트 값:
# F1: 393.12 Hz
# F2: 1763.50 Hz
# --------------------
# phoneme: i
# 구간 36.95-37.02초의 평균 포먼트 값:
# F1: 957.47 Hz
# F2: 2413.07 Hz
# --------------------
# phoneme: ɐ
# 구간 38.70-38.77초의 평균 포먼트 값:
# F1: 838.47 Hz
# F2: 1196.67 Hz
# --------------------
# phoneme: ɛː
# 구간 38.84-39.09초의 평균 포먼트 값:
# F1: 531.03 Hz
# F2: 2168.00 Hz
# --------------------
# phoneme: o
# 구간 40.26-40.29초의 평균 포먼트 값:
# F1: 593.22 Hz
# F2: 1888.05 Hz
# --------------------
# phoneme: ɐ
# 구간 40.53-40.60초의 평균 포먼트 값:
# F1: 978.48 Hz
# F2: 1892.53 Hz
# --------------------
# phoneme: ɐ
# 구간 41.87-41.94초의 평균 포먼트 값:
# F1: 693.87 Hz
# F2: 1548.20 Hz
# --------------------
# phoneme: ɛː
# 구간 42.16-42.26초의 평균 포먼트 값:
# F1: 384.71 Hz
# F2: 1961.86 Hz
# --------------------
# phoneme: ɐ
# 구간 43.58-43.61초의 평균 포먼트 값:
# F1: 978.82 Hz
# F2: 1742.20 Hz
# --------------------
# phoneme: o
# 구간 43.81-43.84초의 평균 포먼트 값:
# F1: 745.62 Hz
# F2: 2083.92 Hz
# --------------------
# phoneme: oː
# 구간 45.27-45.32초의 평균 포먼트 값:
# F1: 547.82 Hz
# F2: 1883.61 Hz
# --------------------
# phoneme: u
# 구간 45.42-45.50초의 평균 포먼트 값:
# F1: 602.73 Hz
# F2: 1219.39 Hz
# --------------------
# phoneme: i
# 구간 46.71-46.79초의 평균 포먼트 값:
# F1: 258.02 Hz
# F2: 2026.47 Hz
# --------------------
# phoneme: i
# 구간 46.86-47.08초의 평균 포먼트 값:
# F1: 423.07 Hz
# F2: 2261.92 Hz
# --------------------
# phoneme: u
# 구간 48.35-48.44초의 평균 포먼트 값:
# F1: 650.97 Hz
# F2: 1930.06 Hz
# --------------------
# phoneme: i
# 구간 48.49-48.62초의 평균 포먼트 값:
# F1: 488.71 Hz
# F2: 2192.35 Hz
# --------------------
# phoneme: ɛː
# 구간 49.83-49.91초의 평균 포먼트 값:
# F1: 455.50 Hz
# F2: 1739.31 Hz
# --------------------
# phoneme: o
# 구간 49.98-50.13초의 평균 포먼트 값:
# F1: 515.34 Hz
# F2: 1966.71 Hz
# --------------------
# phoneme: ɛː
# 구간 51.31-51.39초의 평균 포먼트 값:
# F1: 404.76 Hz
# F2: 1773.06 Hz
# --------------------
# phoneme: ɐ
# 구간 51.48-51.64초의 평균 포먼트 값:
# F1: 792.39 Hz
# F2: 1283.76 Hz
# --------------------
# phoneme: oː
# 구간 52.98-53.08초의 평균 포먼트 값:
# F1: 521.16 Hz
# F2: 1528.01 Hz
# --------------------
# phoneme: o
# 구간 53.15-53.31초의 평균 포먼트 값:
# F1: 586.89 Hz
# F2: 2005.32 Hz
# --------------------
# phoneme: i
# 구간 54.66-54.69초의 평균 포먼트 값:
# F1: 388.37 Hz
# F2: 2149.17 Hz
# --------------------
# phoneme: o
# 구간 54.86-55.03초의 평균 포먼트 값:
# F1: 510.60 Hz
# F2: 1948.40 Hz
# --------------------
# phoneme: ɛː
# 구간 56.26-56.35초의 평균 포먼트 값:
# F1: 421.67 Hz
# F2: 1878.40 Hz
# --------------------
# phoneme: i
# 구간 56.42-56.52초의 평균 포먼트 값:
# F1: 288.72 Hz
# F2: 2152.26 Hz
# --------------------
# phoneme: ɐ
# 구간 57.84-57.88초의 평균 포먼트 값:
# F1: 917.63 Hz
# F2: 1638.05 Hz
# --------------------
# phoneme: ɐ
# 구간 58.07-58.16초의 평균 포먼트 값:
# F1: 867.24 Hz
# F2: 1322.02 Hz
# --------------------
# phoneme: iː
# 구간 59.76-59.82초의 평균 포먼트 값:
# F1: 956.03 Hz
# F2: 2447.19 Hz
# --------------------
# phoneme: ɛː
# 구간 59.87-60.09초의 평균 포먼트 값:
# F1: 494.92 Hz
# F2: 2008.95 Hz
# --------------------
# phoneme: ɐ
# 구간 61.57-61.60초의 평균 포먼트 값:
# F1: 828.55 Hz
# F2: 1552.55 Hz
# --------------------
# phoneme: o
# 구간 61.80-61.89초의 평균 포먼트 값:
# F1: 606.24 Hz
# F2: 1523.89 Hz
# --------------------
# phoneme: i
# 구간 63.66-63.73초의 평균 포먼트 값:
# F1: 278.24 Hz
# F2: 2214.90 Hz
# --------------------
# phoneme: i
# 구간 63.89-63.99초의 평균 포먼트 값:
# F1: 304.13 Hz
# F2: 2289.08 Hz
# --------------------
# phoneme: ɐ
# 구간 65.43-65.48초의 평균 포먼트 값:
# F1: 740.51 Hz
# F2: 1343.89 Hz
# --------------------
# phoneme: ɐ
# 구간 65.73-65.91초의 평균 포먼트 값:
# F1: 859.84 Hz
# F2: 1390.28 Hz
# --------------------
# phoneme: uː
# 구간 68.06-68.17초의 평균 포먼트 값:
# F1: 821.85 Hz
# F2: 2581.76 Hz
# --------------------
# phoneme: ɐ
# 구간 68.27-68.44초의 평균 포먼트 값:
# F1: 847.08 Hz
# F2: 1591.56 Hz
# --------------------
# phoneme: i
# 구간 70.05-70.09초의 평균 포먼트 값:
# F1: 444.72 Hz
# F2: 2130.63 Hz
# --------------------
# phoneme: u
# 구간 70.30-70.40초의 평균 포먼트 값:
# F1: 399.35 Hz
# F2: 1673.87 Hz
# --------------------
# phoneme: u
# 구간 71.98-72.02초의 평균 포먼트 값:
# F1: 365.71 Hz
# F2: 1689.88 Hz
# --------------------
# phoneme: ɛː
# 구간 72.22-72.33초의 평균 포먼트 값:
# F1: 416.40 Hz
# F2: 1891.86 Hz
# --------------------
# phoneme: i
# 구간 74.10-74.14초의 평균 포먼트 값:
# F1: 638.12 Hz
# F2: 2125.74 Hz
# --------------------
# phoneme: o
# 구간 74.34-74.42초의 평균 포먼트 값:
# F1: 577.12 Hz
# F2: 1464.26 Hz
# --------------------
# phoneme: u
# 구간 75.95-75.99초의 평균 포먼트 값:
# F1: 750.20 Hz
# F2: 2053.25 Hz
# --------------------
# phoneme: ɐ
# 구간 76.16-76.26초의 평균 포먼트 값:
# F1: 809.75 Hz
# F2: 1254.78 Hz
# --------------------
# phoneme: u
# 구간 77.87-77.90초의 평균 포먼트 값:
# F1: 528.78 Hz
# F2: 1916.27 Hz
# --------------------
# phoneme: ɛː
# 구간 78.06-78.25초의 평균 포먼트 값:
# F1: 369.41 Hz
# F2: 2051.24 Hz
# --------------------
# phoneme: ɛː
# 구간 79.82-79.90초의 평균 포먼트 값:
# F1: 504.42 Hz
# F2: 1792.40 Hz
# --------------------
# phoneme: u
# 구간 79.96-79.99초의 평균 포먼트 값:
# F1: 928.11 Hz
# F2: 1936.00 Hz
# --------------------
# phoneme: o
# 구간 81.69-81.72초의 평균 포먼트 값:
# F1: 516.16 Hz
# F2: 2066.37 Hz
# --------------------
# phoneme: ɛː
# 구간 81.89-82.11초의 평균 포먼트 값:
# F1: 400.40 Hz
# F2: 1961.19 Hz
# --------------------
# phoneme: ɐ
# 구간 83.72-83.78초의 평균 포먼트 값:
# F1: 887.50 Hz
# F2: 1437.60 Hz
# --------------------
# phoneme: i
# 구간 83.92-84.14초의 평균 포먼트 값:
# F1: 503.95 Hz
# F2: 2252.98 Hz
# --------------------
# phoneme: i
# 구간 85.35-85.43초의 평균 포먼트 값:
# F1: 382.97 Hz
# F2: 1859.37 Hz
# --------------------
# phoneme: ɐ
# 구간 85.56-85.81초의 평균 포먼트 값:
# F1: 727.90 Hz
# F2: 1627.86 Hz
# --------------------
# phoneme: i
# 구간 87.30-87.35초의 평균 포먼트 값:
# F1: 594.07 Hz
# F2: 1968.80 Hz
# --------------------
# phoneme: ɛː
# 구간 87.53-87.67초의 평균 포먼트 값:
# F1: 474.81 Hz
# F2: 1855.02 Hz
# --------------------
# phoneme: ɛː
# 구간 89.20-89.26초의 평균 포먼트 값:
# F1: 440.77 Hz
# F2: 1896.86 Hz
# --------------------
# phoneme: ɛː
# 구간 89.40-89.65초의 평균 포먼트 값:
# F1: 398.65 Hz
# F2: 1989.11 Hz
# --------------------
# phoneme: o
# 구간 91.15-91.22초의 평균 포먼트 값:
# F1: 716.41 Hz
# F2: 1664.14 Hz
# --------------------
# phoneme: i
# 구간 91.40-91.51초의 평균 포먼트 값:
# F1: 412.49 Hz
# F2: 2199.05 Hz
# --------------------
# phoneme: o
# 구간 92.94-93.08초의 평균 포먼트 값:
# F1: 601.80 Hz
# F2: 1906.39 Hz
# --------------------
# phoneme: ɐ
# 구간 93.08-93.14초의 평균 포먼트 값:
# F1: 735.97 Hz
# F2: 956.99 Hz
# --------------------
# phoneme: u
# 구간 94.72-94.76초의 평균 포먼트 값:
# F1: 743.10 Hz
# F2: 2008.84 Hz
# --------------------
# phoneme: i
# 구간 95.02-95.19초의 평균 포먼트 값:
# F1: 347.74 Hz
# F2: 2133.48 Hz
# --------------------
# phoneme: oː
# 구간 96.37-96.40초의 평균 포먼트 값:
# F1: 549.72 Hz
# F2: 1469.18 Hz
# --------------------
# phoneme: u
# 구간 96.62-96.72초의 평균 포먼트 값:
# F1: 503.24 Hz
# F2: 1527.09 Hz
# --------------------
# phoneme: ɛː
# 구간 97.96-98.01초의 평균 포먼트 값:
# F1: 523.00 Hz
# F2: 1785.38 Hz
# --------------------
# phoneme: u
# 구간 98.09-98.15초의 평균 포먼트 값:
# F1: 830.62 Hz
# F2: 1729.80 Hz
# --------------------
# phoneme: i
# 구간 99.59-99.63초의 평균 포먼트 값:
# F1: 513.80 Hz
# F2: 2001.72 Hz
# --------------------
# phoneme: o
# 구간 99.83-99.93초의 평균 포먼트 값:
# F1: 577.93 Hz
# F2: 1552.06 Hz
# --------------------
# phoneme: i
# 구간 101.01-101.05초의 평균 포먼트 값:
# F1: 360.72 Hz
# F2: 1858.81 Hz
# --------------------
# phoneme: ɐ
# 구간 101.27-101.50초의 평균 포먼트 값:
# F1: 813.36 Hz
# F2: 1451.72 Hz
# --------------------
# phoneme: ɛː
# 구간 102.76-102.85초의 평균 포먼트 값:
# F1: 489.01 Hz
# F2: 1715.95 Hz
# --------------------
# phoneme: o
# 구간 102.90-102.96초의 평균 포먼트 값:
# F1: 610.85 Hz
# F2: 2147.91 Hz
# --------------------
# phoneme: ɛː
# 구간 104.15-104.22초의 평균 포먼트 값:
# F1: 388.94 Hz
# F2: 1782.46 Hz
# --------------------
# phoneme: i
# 구간 104.42-104.48초의 평균 포먼트 값:
# F1: 350.60 Hz
# F2: 1948.21 Hz
# --------------------
# phoneme: ɛː
# 구간 105.96-106.08초의 평균 포먼트 값:
# F1: 431.35 Hz
# F2: 1873.48 Hz
# --------------------
# phoneme: ɐ
# 구간 106.18-106.25초의 평균 포먼트 값:
# F1: 882.08 Hz
# F2: 1369.47 Hz
# --------------------
# phoneme: o
# 구간 107.73-107.76초의 평균 포먼트 값:
# F1: 531.88 Hz
# F2: 1816.51 Hz
# --------------------
# phoneme: o
# 구간 107.98-108.09초의 평균 포먼트 값:
# F1: 581.40 Hz
# F2: 1826.20 Hz
# --------------------
# phoneme: i
# 구간 109.56-109.62초의 평균 포먼트 값:
# F1: 640.32 Hz
# F2: 2077.93 Hz
# --------------------
# phoneme: u
# ...
# phoneme: ɐ
# 구간 11.87-12.14초의 평균 포먼트 값:
# F1: 775.84 Hz
# F2: 1323.38 Hz
# --------------------
# phoneme: i
# 구간 12.88-12.93초의 평균 포먼트 값:
# F1: 654.86 Hz
# F2: 2015.75 Hz
# --------------------
# phoneme: ɛː
# 구간 13.13-13.29초의 평균 포먼트 값:
# F1: 547.15 Hz
# F2: 1930.62 Hz
# --------------------
# phoneme: ɛː
# 구간 14.12-14.16초의 평균 포먼트 값:
# F1: 420.61 Hz
# F2: 1741.77 Hz
# --------------------
# phoneme: i
# 구간 14.36-14.45초의 평균 포먼트 값:
# F1: 635.39 Hz
# F2: 2216.96 Hz
# --------------------
# phoneme: ɐ
# 구간 15.34-15.39초의 평균 포먼트 값:
# F1: 795.42 Hz
# F2: 1436.47 Hz
# --------------------
# phoneme: o
# 구간 15.50-15.69초의 평균 포먼트 값:
# F1: 631.73 Hz
# F2: 1387.36 Hz
# --------------------
# phoneme: ɛː
# 구간 16.48-16.55초의 평균 포먼트 값:
# F1: 477.37 Hz
# F2: 1835.53 Hz
# --------------------
# phoneme: o
# 구간 16.60-17.00초의 평균 포먼트 값:
# F1: 626.16 Hz
# F2: 1922.08 Hz
# --------------------
# phoneme: ɐ
# 구간 17.63-17.66초의 평균 포먼트 값:
# F1: 650.91 Hz
# F2: 1323.77 Hz
# --------------------
# phoneme: o
# 구간 17.86-17.99초의 평균 포먼트 값:
# F1: 651.07 Hz
# F2: 2363.35 Hz
# --------------------
# phoneme: ɐ
# 구간 18.79-18.84초의 평균 포먼트 값:
# F1: 657.74 Hz
# F2: 1192.88 Hz
# --------------------
# phoneme: i
# 구간 19.02-19.29초의 평균 포먼트 값:
# F1: 353.41 Hz
# F2: 2166.06 Hz
# --------------------
# phoneme: i
# 구간 19.98-20.05초의 평균 포먼트 값:
# F1: 523.41 Hz
# F2: 1881.09 Hz
# --------------------
# phoneme: o
# 구간 20.19-20.35초의 평균 포먼트 값:
# F1: 734.70 Hz
# F2: 1785.06 Hz
# --------------------
# phoneme: u
# 구간 21.04-21.07초의 평균 포먼트 값:
# F1: 468.76 Hz
# F2: 1641.58 Hz
# --------------------
# phoneme: ɐ
# 구간 21.24-21.40초의 평균 포먼트 값:
# F1: 686.70 Hz
# F2: 1180.39 Hz
# --------------------
# phoneme: ɛː
# 구간 22.10-22.20초의 평균 포먼트 값:
# F1: 483.46 Hz
# F2: 1860.76 Hz
# --------------------
# phoneme: u
# 구간 22.28-22.34초의 평균 포먼트 값:
# F1: 707.69 Hz
# F2: 1495.56 Hz
# --------------------
# phoneme: o
# 구간 23.21-23.37초의 평균 포먼트 값:
# F1: 610.13 Hz
# F2: 1807.01 Hz
# --------------------
# phoneme: ɐ
# 구간 23.37-23.51초의 평균 포먼트 값:
# F1: 719.24 Hz
# F2: 954.35 Hz
# --------------------
# phoneme: i
# 구간 24.15-24.19초의 평균 포먼트 값:
# F1: 286.91 Hz
# F2: 1826.75 Hz
# --------------------
# phoneme: u
# 구간 24.36-24.49초의 평균 포먼트 값:
# F1: 1068.20 Hz
# F2: 2505.13 Hz
# --------------------
# phoneme: i
# 구간 25.19-25.26초의 평균 포먼트 값:
# F1: 281.09 Hz
# F2: 2118.22 Hz
# --------------------
# phoneme: i
# 구간 25.40-25.54초의 평균 포먼트 값:
# F1: 364.50 Hz
# F2: 2189.37 Hz
# --------------------
# phoneme: ɐ
# 구간 26.18-26.25초의 평균 포먼트 값:
# F1: 762.08 Hz
# F2: 1009.06 Hz
# --------------------
# phoneme: u
# 구간 26.45-26.65초의 평균 포먼트 값:
# F1: 781.19 Hz
# F2: 2016.06 Hz
# --------------------
# phoneme: i
# 구간 27.25-27.34초의 평균 포먼트 값:
# F1: 666.01 Hz
# F2: 2214.76 Hz
# --------------------
# phoneme: u
# 구간 27.42-27.53초의 평균 포먼트 값:
# F1: 518.71 Hz
# F2: 1075.78 Hz
# --------------------
# phoneme: ɛː
# 구간 28.26-28.30초의 평균 포먼트 값:
# F1: 487.31 Hz
# F2: 2008.94 Hz
# --------------------
# phoneme: ɛː
# 구간 28.46-28.68초의 평균 포먼트 값:
# F1: 521.60 Hz
# F2: 1901.54 Hz
# --------------------
# phoneme: iː
# 구간 29.25-29.37초의 평균 포먼트 값:
# F1: 319.32 Hz
# F2: 2110.92 Hz
# --------------------
# phoneme: ɛː
# 구간 29.44-29.66초의 평균 포먼트 값:
# F1: 480.61 Hz
# F2: 1874.11 Hz
# --------------------
# phoneme: i
# 구간 30.24-30.30초의 평균 포먼트 값:
# F1: 432.49 Hz
# F2: 2061.76 Hz
# --------------------
# phoneme: o
# 구간 30.49-30.62초의 평균 포먼트 값:
# F1: 541.88 Hz
# F2: 2094.85 Hz
# --------------------
# phoneme: ɛː
# 구간 31.14-31.28초의 평균 포먼트 값:
# F1: 506.30 Hz
# F2: 1972.25 Hz
# --------------------
# phoneme: o
# 구간 31.35-31.52초의 평균 포먼트 값:
# F1: 581.82 Hz
# F2: 2451.70 Hz
# --------------------
# phoneme: ɐ
# 구간 32.15-32.30초의 평균 포먼트 값:
# F1: 740.01 Hz
# F2: 1002.07 Hz
# --------------------
# phoneme: u
# 구간 32.35-32.46초의 평균 포먼트 값:
# F1: 713.78 Hz
# F2: 2521.47 Hz
# --------------------
# phoneme: oː
# 구간 33.17-33.28초의 평균 포먼트 값:
# F1: 479.01 Hz
# F2: 1651.73 Hz
# --------------------
# phoneme: u
# 구간 33.36-33.45초의 평균 포먼트 값:
# F1: 560.66 Hz
# F2: 1114.15 Hz
# --------------------
# phoneme: ɛː
# 구간 34.07-34.20초의 평균 포먼트 값:
# F1: 418.85 Hz
# F2: 1893.97 Hz
# --------------------
# phoneme: i
# 구간 34.28-34.40초의 평균 포먼트 값:
# F1: 295.02 Hz
# F2: 2026.94 Hz
# --------------------
# phoneme: oː
# 구간 35.03-35.08초의 평균 포먼트 값:
# F1: 524.30 Hz
# F2: 1621.66 Hz
# --------------------
# phoneme: u
# 구간 35.27-35.55초의 평균 포먼트 값:
# F1: 582.80 Hz
# F2: 2101.02 Hz
# --------------------
# phoneme: u
# 구간 36.13-36.19초의 평균 포먼트 값:
# F1: 946.19 Hz
# F2: 1940.98 Hz
# --------------------
# phoneme: i
# 구간 36.39-36.62초의 평균 포먼트 값:
# F1: 444.03 Hz
# F2: 2152.17 Hz
# --------------------
# phoneme: u
# 구간 37.09-37.17초의 평균 포먼트 값:
# F1: 322.68 Hz
# F2: 1508.89 Hz
# --------------------
# phoneme: o
# 구간 37.34-37.57초의 평균 포먼트 값:
# F1: 493.38 Hz
# F2: 994.56 Hz
# --------------------
# phoneme: ɐ
# 구간 38.09-38.16초의 평균 포먼트 값:
# F1: 710.85 Hz
# F2: 1403.61 Hz
# --------------------
# phoneme: i
# 구간 38.37-38.61초의 평균 포먼트 값:
# F1: 456.06 Hz
# F2: 2200.87 Hz
# --------------------
# phoneme: o
# 구간 39.13-39.20초의 평균 포먼트 값:
# F1: 403.99 Hz
# F2: 1308.25 Hz
# --------------------
# phoneme: i
# 구간 39.39-39.52초의 평균 포먼트 값:
# F1: 344.42 Hz
# F2: 2180.10 Hz
# --------------------
# phoneme: ɛː
# 구간 40.18-40.29초의 평균 포먼트 값:
# F1: 469.30 Hz
# F2: 1673.09 Hz
# --------------------
# phoneme: ɐ
# 구간 40.41-40.56초의 평균 포먼트 값:
# F1: 841.80 Hz
# F2: 1268.15 Hz
# --------------------
# phoneme: o
# 구간 41.21-41.29초의 평균 포먼트 값:
# F1: 342.40 Hz
# F2: 988.19 Hz
# --------------------
# phoneme: ɛː
# 구간 41.47-41.76초의 평균 포먼트 값:
# F1: 465.85 Hz
# F2: 2022.37 Hz
# --------------------
# phoneme: o
# 구간 42.23-42.27초의 평균 포먼트 값:
# F1: 555.77 Hz
# F2: 2104.63 Hz
# --------------------
# phoneme: o
# 구간 42.47-42.63초의 평균 포먼트 값:
# F1: 630.57 Hz
# F2: 2651.97 Hz
# --------------------
# phoneme: oː
# 구간 43.72-43.86초의 평균 포먼트 값:
# F1: 590.05 Hz
# F2: 1464.20 Hz
# --------------------
# phoneme: o
# 구간 43.93-44.16초의 평균 포먼트 값:
# F1: 606.36 Hz
# F2: 1874.30 Hz
# --------------------
# phoneme: ɐ
# 구간 44.60-44.69초의 평균 포먼트 값:
# F1: 723.01 Hz
# F2: 1359.08 Hz
# --------------------
# phoneme: ɐ
# 구간 44.89-45.14초의 평균 포먼트 값:
# F1: 862.11 Hz
# F2: 1539.19 Hz
# --------------------
# phoneme: ɐ
# 구간 45.65-45.73초의 평균 포먼트 값:
# F1: 666.28 Hz
# F2: 1363.81 Hz
# --------------------
# phoneme: ɛː
# 구간 45.90-46.05초의 평균 포먼트 값:
# F1: 492.50 Hz
# F2: 1933.33 Hz
# --------------------
# phoneme: u
# 구간 46.72-46.86초의 평균 포먼트 값:
# F1: 666.60 Hz
# F2: 2455.49 Hz
# --------------------
# phoneme: u
# 구간 46.91-47.05초의 평균 포먼트 값:
# F1: 725.12 Hz
# F2: 2551.13 Hz
# --------------------
# phoneme: o
# 구간 47.71-47.77초의 평균 포먼트 값:
# F1: 503.88 Hz
# F2: 1758.13 Hz
# --------------------
# phoneme: ɛː
# 구간 47.99-48.27초의 평균 포먼트 값:
# F1: 571.07 Hz
# F2: 1941.43 Hz
# --------------------
# phoneme: ɛː
# 구간 48.74-48.83초의 평균 포먼트 값:
# F1: 419.88 Hz
# F2: 1921.82 Hz
# --------------------
# phoneme: ɛː
# 구간 49.01-49.25초의 평균 포먼트 값:
# F1: 513.96 Hz
# F2: 1904.12 Hz
# --------------------
# phoneme: o
# 구간 49.84-49.92초의 평균 포먼트 값:
# F1: 541.68 Hz
# F2: 2587.03 Hz
# --------------------
# phoneme: i
# 구간 50.15-50.39초의 평균 포먼트 값:
# F1: 599.01 Hz
# F2: 2219.65 Hz
# --------------------
# phoneme: ɐ
# 구간 50.92-50.96초의 평균 포먼트 값:
# F1: 920.50 Hz
# F2: 1035.59 Hz
# --------------------
# phoneme: ɛː
# 구간 50.96-50.99초의 평균 포먼트 값:
# F1: 809.11 Hz
# F2: 1048.88 Hz
# --------------------
# phoneme: i
# 구간 52.01-52.09초의 평균 포먼트 값:
# F1: 275.28 Hz
# F2: 1910.31 Hz
# --------------------
# phoneme: ɐ
# 구간 52.27-52.50초의 평균 포먼트 값:
# F1: 748.92 Hz
# F2: 1064.85 Hz
# --------------------
# phoneme: ɐ
# 구간 53.06-53.15초의 평균 포먼트 값:
# F1: 698.66 Hz
# F2: 1627.55 Hz
# --------------------
# phoneme: ɐ
# 구간 53.35-53.46초의 평균 포먼트 값:
# F1: 866.43 Hz
# F2: 1463.61 Hz
# --------------------
# phoneme: ɛː
# 구간 54.15-54.22초의 평균 포먼트 값:
# F1: 466.50 Hz
# F2: 1789.96 Hz
# --------------------
# phoneme: u
# 구간 54.43-54.52초의 평균 포먼트 값:
# F1: 822.94 Hz
# F2: 2406.96 Hz
# --------------------
# phoneme: u
# 구간 55.16-55.29초의 평균 포먼트 값:
# F1: 561.15 Hz
# F2: 1828.26 Hz
# --------------------
# phoneme: ɛː
# 구간 55.55-55.67초의 평균 포먼트 값:
# F1: 502.22 Hz
# F2: 1935.06 Hz
# --------------------
# phoneme: u
# 구간 56.41-56.54초의 평균 포먼트 값:
# F1: 919.61 Hz
# F2: 2117.44 Hz
# --------------------
# phoneme: i
# 구간 56.61-56.73초의 평균 포먼트 값:
# F1: 1202.08 Hz
# F2: 2553.38 Hz
# --------------------
# phoneme: u
# 구간 57.47-57.66초의 평균 포먼트 값:
# F1: 444.55 Hz
# F2: 1774.36 Hz
# --------------------
# phoneme: o
# 구간 57.70-57.80초의 평균 포먼트 값:
# F1: 538.79 Hz
# F2: 1567.57 Hz
# --------------------
# phoneme: uː
# 구간 58.59-58.70초의 평균 포먼트 값:
# F1: 623.22 Hz
# F2: 1931.90 Hz
# --------------------
# phoneme: ɐ
# 구간 58.83-59.02초의 평균 포먼트 값:
# F1: 777.74 Hz
# F2: 1233.39 Hz
# --------------------
# phoneme: ɛː
# 구간 59.59-59.75초의 평균 포먼트 값:
# F1: 441.14 Hz
# F2: 1819.73 Hz
# --------------------
# phoneme: ɐ
# 구간 59.85-60.09초의 평균 포먼트 값:
# F1: 766.42 Hz
# F2: 1377.20 Hz
# --------------------
# phoneme: u
# 구간 60.70-60.74초의 평균 포먼트 값:
# F1: 1282.99 Hz
# F2: 2517.80 Hz
# --------------------
# phoneme: ɛː
# 구간 60.95-61.21초의 평균 포먼트 값:
# F1: 459.18 Hz
# F2: 1992.56 Hz
# --------------------
# phoneme: u
# 구간 61.78-61.81초의 평균 포먼트 값:
# F1: 444.65 Hz
# F2: 1921.54 Hz
# --------------------
# phoneme: u
# 구간 61.81-62.10초의 평균 포먼트 값:
# F1: 597.73 Hz
# F2: 2381.91 Hz
# --------------------
# phoneme: i
# 구간 62.82-62.96초의 평균 포먼트 값:
# F1: 262.97 Hz
# F2: 2068.00 Hz
# --------------------
# phoneme: i
# 구간 63.03-63.27초의 평균 포먼트 값:
# F1: 395.69 Hz
# F2: 2262.62 Hz
# --------------------
# total detected phonemes: 100
# 파일 정보:
# 전체 길이: 10.407초
# Tier 목록: ['words', 'phones']
#
# ==================================================
#
# Tier: phones
# ------------------------------
# <class 'list'>
# phoneme: i
# 구간 4.53-4.78초의 평균 포먼트 값:
# F1: 401.08 Hz
# F2: 2155.49 Hz
# --------------------
# 구간 5.28-6.19초의 평균 포먼트 값:
# detection failed.
# F1: None
# F2: None
# 구간 6.74-7.23초의 평균 포먼트 값:
# detection failed.
# F1: None
# F2: None
# total detected phonemes: 5
# 파일 정보:
# 전체 길이: 65.636초
# Tier 목록: ['words', 'phones']
#
# ==================================================
#
# Tier: phones
# ------------------------------
# <class 'list'>
# phoneme: u
# 구간 1.79-1.91초의 평균 포먼트 값:
# F1: 457.38 Hz
# F2: 1262.61 Hz
# --------------------
# phoneme: o
# 구간 1.99-2.10초의 평균 포먼트 값:
# F1: 726.64 Hz
# F2: 2103.10 Hz
# --------------------
# phoneme: ɐ
# 구간 3.09-3.18초의 평균 포먼트 값:
# F1: 700.76 Hz
# F2: 1158.03 Hz
# --------------------
# phoneme: u
# 구간 3.37-3.60초의 평균 포먼트 값:
# F1: 535.54 Hz
# F2: 1581.04 Hz
# --------------------
# phoneme: ɛː
# 구간 4.38-4.44초의 평균 포먼트 값:
# F1: 493.64 Hz
# F2: 2028.85 Hz
# --------------------
# phoneme: ɛː
# 구간 4.66-4.85초의 평균 포먼트 값:
# F1: 483.43 Hz
# F2: 1929.32 Hz
# --------------------
# phoneme: o
# 구간 5.75-5.78초의 평균 포먼트 값:
# F1: 681.26 Hz
# F2: 1166.02 Hz
# --------------------
# phoneme: ɐ
# 구간 5.78-5.89초의 평균 포먼트 값:
# F1: 750.16 Hz
# F2: 1172.98 Hz
# --------------------
# phoneme: u
# 구간 6.76-6.82초의 평균 포먼트 값:
# F1: 442.15 Hz
# F2: 1573.80 Hz
# --------------------
# phoneme: ɛː
# 구간 7.05-7.31초의 평균 포먼트 값:
# F1: 438.32 Hz
# F2: 2048.67 Hz
# --------------------
# phoneme: u
# 구간 7.95-8.07초의 평균 포먼트 값:
# F1: 622.50 Hz
# F2: 1842.73 Hz
# --------------------
# phoneme: i
# 구간 8.17-8.27초의 평균 포먼트 값:
# F1: 369.72 Hz
# F2: 2100.59 Hz
# --------------------
# phoneme: ɐ
# 구간 9.24-9.35초의 평균 포먼트 값:
# F1: 789.75 Hz
# F2: 1284.55 Hz
# --------------------
# phoneme: ɛː
# 구간 9.43-9.67초의 평균 포먼트 값:
# F1: 451.16 Hz
# F2: 2012.65 Hz
# --------------------
# phoneme: ɛː
# 구간 10.47-10.59초의 평균 포먼트 값:
# F1: 481.25 Hz
# F2: 1955.57 Hz
# --------------------
# phoneme: u
# 구간 10.67-10.73초의 평균 포먼트 값:
# F1: 641.38 Hz
# F2: 1753.91 Hz
# --------------------
# phoneme: u
# 구간 11.58-11.64초의 평균 포먼트 값:
# F1: 463.34 Hz
# F2: 1374.99 Hz
# --------------------
# phoneme: i
# 구간 11.89-12.11초의 평균 포먼트 값:
# F1: 381.70 Hz
# F2: 2196.44 Hz
# --------------------
# phoneme: ɐ
# 구간 12.83-12.90초의 평균 포먼트 값:
# F1: 733.73 Hz
# F2: 1192.93 Hz
# --------------------
# phoneme: o
# 구간 13.08-13.26초의 평균 포먼트 값:
# F1: 557.59 Hz
# F2: 871.96 Hz
# --------------------
# phoneme: u
# 구간 14.16-14.19초의 평균 포먼트 값:
# F1: 676.41 Hz
# F2: 2261.20 Hz
# --------------------
# phoneme: u
# 구간 14.19-14.60초의 평균 포먼트 값:
# F1: 531.47 Hz
# F2: 1669.84 Hz
# --------------------
# phoneme: o
# 구간 15.39-15.44초의 평균 포먼트 값:
# F1: 550.01 Hz
# F2: 2122.47 Hz
# --------------------
# phoneme: o
# 구간 15.68-15.82초의 평균 포먼트 값:
# F1: 458.15 Hz
# F2: 1106.20 Hz
# --------------------
# phoneme: ɛː
# 구간 16.73-16.80초의 평균 포먼트 값:
# F1: 467.80 Hz
# F2: 1882.62 Hz
# --------------------
# phoneme: u
# 구간 17.05-17.15초의 평균 포먼트 값:
# F1: 1220.90 Hz
# F2: 2263.06 Hz
# --------------------
# phoneme: u
# 구간 18.05-18.10초의 평균 포먼트 값:
# F1: 664.34 Hz
# F2: 2070.48 Hz
# --------------------
# phoneme: ɐ
# 구간 18.33-18.45초의 평균 포먼트 값:
# F1: 748.31 Hz
# F2: 1262.74 Hz
# --------------------
# phoneme: u
# 구간 19.36-19.52초의 평균 포먼트 값:
# F1: 842.78 Hz
# F2: 2657.97 Hz
# --------------------
# phoneme: u
# 구간 19.57-19.70초의 평균 포먼트 값:
# F1: 754.03 Hz
# F2: 2839.89 Hz
# --------------------
# phoneme: o
# 구간 20.73-20.80초의 평균 포먼트 값:
# F1: 448.45 Hz
# F2: 1185.31 Hz
# --------------------
# phoneme: ɐ
# 구간 21.00-21.14초의 평균 포먼트 값:
# F1: 740.33 Hz
# F2: 1157.32 Hz
# --------------------
# phoneme: oː
# 구간 22.04-22.13초의 평균 포먼트 값:
# F1: 590.53 Hz
# F2: 1888.40 Hz
# --------------------
# phoneme: u
# 구간 22.37-22.65초의 평균 포먼트 값:
# F1: 517.82 Hz
# F2: 2058.94 Hz
# --------------------
# phoneme: ɐ
# 구간 23.76-23.90초의 평균 포먼트 값:
# F1: 734.97 Hz
# F2: 1140.80 Hz
# --------------------
# phoneme: u
# 구간 23.98-24.12초의 평균 포먼트 값:
# F1: 594.59 Hz
# F2: 2177.25 Hz
# --------------------
# phoneme: i
# 구간 25.01-25.06초의 평균 포먼트 값:
# F1: 355.69 Hz
# F2: 1994.39 Hz
# --------------------
# phoneme: ɛː
# 구간 25.32-25.46초의 평균 포먼트 값:
# F1: 476.38 Hz
# F2: 1987.01 Hz
# --------------------
# phoneme: ɐ
# 구간 26.21-26.33초의 평균 포먼트 값:
# F1: 696.49 Hz
# F2: 1506.15 Hz
# --------------------
# phoneme: ɐ
# 구간 26.55-26.70초의 평균 포먼트 값:
# F1: 774.81 Hz
# F2: 1151.74 Hz
# --------------------
# phoneme: ɛː
# 구간 28.20-28.30초의 평균 포먼트 값:
# F1: 451.64 Hz
# F2: 1897.53 Hz
# --------------------
# phoneme: o
# 구간 28.49-28.85초의 평균 포먼트 값:
# F1: 519.99 Hz
# F2: 1882.68 Hz
# --------------------
# phoneme: ɛː
# 구간 29.53-29.63초의 평균 포먼트 값:
# F1: 467.55 Hz
# F2: 1875.25 Hz
# --------------------
# phoneme: ɛː
# 구간 29.88-30.15초의 평균 포먼트 값:
# F1: 497.47 Hz
# F2: 1918.85 Hz
# --------------------
# phoneme: u
# 구간 31.01-31.08초의 평균 포먼트 값:
# F1: 1032.07 Hz
# F2: 2052.93 Hz
# --------------------
# phoneme: ɛː
# 구간 31.36-31.50초의 평균 포먼트 값:
# F1: 509.97 Hz
# F2: 1986.69 Hz
# --------------------
# phoneme: i
# 구간 32.34-32.42초의 평균 포먼트 값:
# F1: 320.09 Hz
# F2: 2335.21 Hz
# --------------------
# phoneme: ɐ
# 구간 32.63-32.90초의 평균 포먼트 값:
# F1: 709.85 Hz
# F2: 1378.34 Hz
# --------------------
# phoneme: ɐ
# 구간 33.50-33.61초의 평균 포먼트 값:
# F1: 767.76 Hz
# F2: 1351.21 Hz
# --------------------
# phoneme: ɛː
# 구간 33.86-33.97초의 평균 포먼트 값:
# F1: 478.81 Hz
# F2: 1950.57 Hz
# --------------------
# phoneme: ɛː
# 구간 34.81-34.98초의 평균 포먼트 값:
# F1: 446.44 Hz
# F2: 1902.59 Hz
# --------------------
# phoneme: ɐ
# 구간 35.08-35.35초의 평균 포먼트 값:
# F1: 817.03 Hz
# F2: 1408.65 Hz
# --------------------
# phoneme: o
# 구간 36.01-36.12초의 평균 포먼트 값:
# F1: 517.35 Hz
# F2: 1528.37 Hz
# --------------------
# phoneme: ɛː
# 구간 36.33-36.60초의 평균 포먼트 값:
# F1: 452.85 Hz
# F2: 2000.82 Hz
# --------------------
# phoneme: u
# 구간 37.33-37.40초의 평균 포먼트 값:
# F1: 736.60 Hz
# F2: 1738.82 Hz
# --------------------
# phoneme: o
# 구간 37.64-37.97초의 평균 포먼트 값:
# F1: 550.61 Hz
# F2: 1736.95 Hz
# --------------------
# phoneme: ɐ
# 구간 38.65-38.73초의 평균 포먼트 값:
# F1: 855.04 Hz
# F2: 1374.68 Hz
# --------------------
# phoneme: i
# 구간 38.98-39.29초의 평균 포먼트 값:
# F1: 387.37 Hz
# F2: 2174.34 Hz
# --------------------
# phoneme: i
# 구간 39.98-40.06초의 평균 포먼트 값:
# F1: 337.42 Hz
# F2: 2202.07 Hz
# --------------------
# phoneme: i
# 구간 40.28-40.36초의 평균 포먼트 값:
# F1: 396.56 Hz
# F2: 2246.57 Hz
# --------------------
# phoneme: ɛː
# 구간 41.28-41.35초의 평균 포먼트 값:
# F1: 427.44 Hz
# F2: 1867.79 Hz
# --------------------
# phoneme: ɐ
# 구간 41.53-41.65초의 평균 포먼트 값:
# F1: 806.33 Hz
# F2: 1225.77 Hz
# --------------------
# phoneme: i
# 구간 42.54-42.61초의 평균 포먼트 값:
# F1: 346.99 Hz
# F2: 2142.04 Hz
# --------------------
# phoneme: o
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 14
#      12 textgrids_list.sort()
#      13 for textgrid in textgrids_list:
# ---> 14     detect_formants(participant_path, textgrid)
#
# Cell In[77], line 56, in detect_formants(participant_path, textGrid_name)
#      54 phoneme_cnt+=1
#      55 wav_file_name = textGrid_name.replace(".TextGrid", ".wav")
# ---> 56 avg_f1, avg_f2 = get_average_formants(os.path.join(participant_path, wav_file_name), start, end)
#      58 if avg_f1 is not None and avg_f2 is not None:
#      59     print(f"구간 {start:.2f}-{end:.2f}초의 평균 포먼트 값:")
#
# Cell In[66], line 21, in get_average_formants(wav_path, start_time, end_time, time_step)
#      18 snd = parselmouth.Sound(wav_path)
#      20 # Formant 객체 생성 (Praat의 Formant settings와 동일한 파라미터 사용)
# ---> 21 formant = snd.to_formant_burg(
#      22     max_number_of_formants=5,  # Praat 기본값: 5
#      23     maximum_formant=5500,      # Praat 기본값: 5500 Hz (여성)
#      24     window_length=0.025,       # Praat 기본값: 0.025초
#      25     pre_emphasis_from=50,      # Praat 기본값: 50 Hz
#      26     time_step=0.025/4 # 시간 간격
#      27 )
#      29 # 시간 포인트 생성
#      30 time_points = np.arange(start_time, end_time, time_step)
#
# KeyboardInterrupt:

# %%
# 개선: 병렬 처리 적용
from concurrent.futures import ProcessPoolExecutor
import multiprocessing

def process_participant(participant):
    participant_path = os.path.join(expPath, participant)
    file_list = os.listdir(participant_path)
    
    if len(file_list) == 0:
        print(ValueError(f"No files found in {participant_path}"))
        return
    
    if any(csv_file.endswith(".csv") for csv_file in file_list):
        print(f"{participant} already analyzed.")
        return
    textgrids_path = os.path.join(participant_path, "output-new")
    
    textgrids_list = os.listdir(textgrids_path)
    textgrids_list = [file for file in textgrids_list if file.endswith(".TextGrid")]
    textgrids_list.sort()
    for textgrid in textgrids_list:
        detect_formants(participant_path, textgrid)
    return results

# CPU 코어 수에 맞춰 병렬 처리
with ProcessPoolExecutor(max_workers=int(0.4*multiprocessing.cpu_count())) as executor:
    results = list(executor.map(process_participant, participant_list))
# Out:
# Process SpawnProcess-18:
# Process SpawnProcess-16:
# Process SpawnProcess-17:
# Process SpawnProcess-15:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/process.py", line 252, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/process.py", line 252, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'process_participant' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# AttributeError: Can't get attribute 'process_participant' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/process.py", line 252, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'process_participant' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/process.py", line 252, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'process_participant' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# Cell In[89], line 27
#      25 # CPU 코어 수에 맞춰 병렬 처리
#      26 with ProcessPoolExecutor(max_workers=int(0.4*multiprocessing.cpu_count())) as executor:
# ---> 27     results = list(executor.map(process_participant, participant_list))
#
# File /opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/process.py:636, in _chain_from_iterable_of_lists(iterable)
#     630 def _chain_from_iterable_of_lists(iterable):
#     631     """
#     632     Specialized implementation of itertools.chain.from_iterable.
#     633     Each item in *iterable* should be a list.  This function is
#     634     careful not to keep references to yielded objects.
#     635     """
# --> 636     for element in iterable:
#     637         element.reverse()
#     638         while element:
#
# File /opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File /opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File /opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.

# %%
import os
import numpy as np
import pandas as pd
import parselmouth
from concurrent.futures import ProcessPoolExecutor
import multiprocessing
from tqdm import tqdm
import logging
from functools import partial
import time

# 로깅 설정
logging.basicConfig(
    filename='formant_analysis.log',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

def process_single_textgrid(participant_path, textgrid):
    """
    단일 TextGrid 파일 처리
    """
    try:
        textgrid_path = os.path.join(participant_path, "output-new", textgrid)
        reader = TextGridReader(textgrid_path)
        tiers_data = reader.read()
        
        phonemes = []
        f1_values = []
        f2_values = []
        
        for tier_name in reader.get_tier_names():
            if tier_name == "words":
                continue
                
            intervals = reader.get_intervals_by_tier(tier_name)
            for start, end, text in intervals:
                if text == "":
                    continue
                    
                if text == "spn":
                    phonemes.extend([None, None])
                    f1_values.extend([None, None])
                    f2_values.extend([None, None])
                    continue
                    
                if text not in ["ɐ","ɐː", "ɛ", "ɛː", "i", "iː", "o", "oː", "u", "uː"]:
                    continue
                    
                wav_file_name = textgrid.replace(".TextGrid", ".wav")
                wav_path = os.path.join(participant_path, wav_file_name)
                
                # 포먼트 분석
                snd = parselmouth.Sound(wav_path)
                formant = snd.to_formant_burg(
                    max_number_of_formants=5,
                    maximum_formant=5500,
                    window_length=0.025,
                    pre_emphasis_from=50,
                    time_step=0.025/4
                )
                
                time_points = np.arange(start, end, 0.025/4)
                f1_values_temp = []
                f2_values_temp = []
                
                for time in time_points:
                    f1 = formant.get_value_at_time(1, time)
                    f2 = formant.get_value_at_time(2, time)
                    
                    if not np.isnan(f1):
                        f1_values_temp.append(f1)
                    if not np.isnan(f2):
                        f2_values_temp.append(f2)
                
                avg_f1 = np.mean(f1_values_temp) if f1_values_temp else None
                avg_f2 = np.mean(f2_values_temp) if f2_values_temp else None
                
                phonemes.append(text)
                f1_values.append(avg_f1)
                f2_values.append(avg_f2)
        
        # 결과 저장
        pandas_data = pd.DataFrame({
            "phoneme": phonemes,
            "f1": f1_values,
            "f2": f2_values
        })
        
        output_path = os.path.join(participant_path, textgrid.replace(".TextGrid", ".csv"))
        pandas_data.to_csv(output_path, index=False)
        
        return True
    except Exception as e:
        logging.error(f"Error processing {textgrid}: {str(e)}")
        return False

def process_participant(args):
    """
    단일 참가자 처리 함수
    """
    participant, expPath = args
    try:
        participant_path = os.path.join(expPath, participant)
        textgrids_path = os.path.join(participant_path, "output-new")
        
        if not os.path.exists(textgrids_path):
            logging.error(f"Directory not found: {textgrids_path}")
            return False
        
        if any(csv_file.endswith(".csv") for csv_file in os.listdir(textgrids_path)):
            print(f"{participant} already analyzed.")
            return True
            
        textgrids_list = [f for f in os.listdir(textgrids_path) if f.endswith(".TextGrid")]
        textgrids_list.sort()
        
        results = []
        for textgrid in textgrids_list:
            result = process_single_textgrid(participant_path, textgrid)
            results.append(result)
        
        return all(results)
    except Exception as e:
        logging.error(f"Error processing participant {participant}: {str(e)}")
        return False

def main():
    # 기본 경로 설정
    expPath = "/Users/bagjuhyeon/Desktop/results"
    participant_list = [f for f in os.listdir(expPath) if "participant_LY" in f]
    participant_list.sort()
    
    # CPU 코어 수 설정 (전체 코어의 50%만 사용)
    num_cores = max(1, int(multiprocessing.cpu_count() * 0.5))
    
    # 작업 인자 준비
    work_args = [(participant, expPath) for participant in participant_list]
    
    # 진행 상황 표시를 위한 tqdm 설정
    with tqdm(total=len(participant_list), desc="Processing participants") as pbar:
        # ProcessPoolExecutor를 사용한 병렬 처리
        with ProcessPoolExecutor(max_workers=num_cores) as executor:
            # 작업 제출
            futures = [executor.submit(process_participant, args) for args in work_args]
            
            # 결과 처리
            for future in futures:
                try:
                    result = future.result(timeout=3600)  # 1시간 타임아웃 설정
                    if not result:
                        logging.warning("Some processing failed")
                except Exception as e:
                    logging.error(f"Error in parallel processing: {str(e)}")
                finally:
                    pbar.update(1)
                    time.sleep(0.1)  # CPU 부하 감소를 위한 짧은 대기

if __name__ == "__main__":
    # Windows에서 실행할 경우 필요
    multiprocessing.freeze_support()
    main()
# Out:
# Processing participants:   0%|          | 0/37 [00:00<?, ?it/s]Process SpawnProcess-28:
# Process SpawnProcess-25:
# Process SpawnProcess-26:
# Process SpawnProcess-27:
# Process SpawnProcess-24:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/process.py", line 252, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/process.py", line 252, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# AttributeError: Can't get attribute 'process_participant' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/process.py", line 252, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# AttributeError: Can't get attribute 'process_participant' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/process.py", line 252, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/concurrent/futures/process.py", line 252, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'process_participant' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
#   File "/opt/anaconda3/envs/phoneticConvergenceAnalysis/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'process_participant' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# AttributeError: Can't get attribute 'process_participant' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Processing participants: 100%|██████████| 37/37 [00:04<00:00,  9.05it/s]

# %% [markdown]
# ## File gen

# %%
import os
import shutil
import glob

def move_files(source_dir, target_dir, file_pattern="*"):
    """
    특정 폴더 내의 파일들을 다른 폴더로 이동
    
    Args:
        source_dir (str): 소스 폴더 경로
        target_dir (str): 대상 폴더 경로
        file_pattern (str): 이동할 파일 패턴 (기본값: "*")
    """
    try:
        # 대상 폴더가 없으면 생성
        if not os.path.exists(target_dir):
            os.makedirs(target_dir)
            
        # 소스 폴더 내의 모든 파일 경로 가져오기
        file_paths = glob.glob(os.path.join(source_dir, file_pattern))
        
        # 파일 이동
        for file_path in file_paths:
            if os.path.isfile(file_path):  # 파일인 경우에만 이동
                file_name = os.path.basename(file_path)
                target_path = os.path.join(target_dir, file_name)
                
                # 파일 이동
                shutil.move(file_path, target_path)
                print(f"이동 완료: {file_name}")
                
        print(f"총 {len(file_paths)}개의 파일 이동이 완료되었습니다.")
        
    except Exception as e:
        print(f"에러 발생: {str(e)}")

def delete_files(directory, file_pattern="*"):
    """
    특정 폴더 내의 파일들을 삭제
    
    Args:
        directory (str): 파일이 있는 폴더 경로
        file_pattern (str): 삭제할 파일 패턴 (기본값: "*")
    """
    try:
        # 폴더 내의 모든 파일 경로 가져오기
        file_paths = glob.glob(os.path.join(directory, file_pattern))
        
        # 파일 삭제
        for file_path in file_paths:
            if os.path.isfile(file_path):  # 파일인 경우에만 삭제
                os.remove(file_path)
                print(f"삭제 완료: {os.path.basename(file_path)}")
                
        print(f"총 {len(file_paths)}개의 파일 삭제가 완료되었습니다.")
        
    except Exception as e:
        print(f"에러 발생: {str(e)}")

def clear_directory(directory_path):
    """
    특정 폴더 내의 모든 파일과 하위 폴더를 삭제
    
    Args:
        directory_path (str): 삭제할 파일들이 있는 폴더 경로
    """
    try:
        # 폴더가 존재하는지 확인
        if not os.path.exists(directory_path):
            print(f"폴더가 존재하지 않습니다: {directory_path}")
            return
            
        # 폴더 내의 모든 항목 삭제
        for item in os.listdir(directory_path):
            item_path = os.path.join(directory_path, item)
            
            if os.path.isfile(item_path):
                # 파일인 경우 삭제
                os.remove(item_path)
                print(f"파일 삭제 완료: {item}")
            elif os.path.isdir(item_path):
                # 하위 폴더인 경우 폴더와 그 내용을 모두 삭제
                shutil.rmtree(item_path)
                print(f"폴더 삭제 완료: {item}")
                
        print(f"\n{directory_path} 폴더의 모든 내용이 삭제되었습니다.")
        
    except Exception as e:
        print(f"에러 발생: {str(e)}")

# %%
# 사용 예시
source_directory = "source_folder"  # 소스 폴더 경로
target_directory = "target_folder"  # 대상 폴더 경로
file_pattern = "*.txt"  # 이동할 파일 패턴 (예: 모든 txt 파일)

move_files(source_directory, target_directory, file_pattern)

# 사용 예시
target_directory = "target_folder"  # 삭제할 파일이 있는 폴더 경로
file_pattern = "*.txt"  # 삭제할 파일 패턴 (예: 모든 txt 파일)

delete_files(target_directory, file_pattern)

# %%
folderPath = "/Users/bagjuhyeon/Desktop/results-KFA"
participants_list = os.listdir(folderPath)
participants_list.sort()
participants_list = [participant for participant in participants_list if "participant_LY" in participant]

for participant in participants_list:
    participant_path = os.path.join(folderPath, participant)
    
    file_list = os.listdir(participant_path)

    if "KFA" in file_list:
        kfa_path = os.path.join(participant_path, "KFA")
        delete_files(participant_path, "*.wav")
        delete_files(participant_path, "*.TextGrid")
        delete_files(participant_path, "*.lab")
        delete_files(participant_path, "*.txt")
        delete_files(participant_path, "*.csv")
        delete_files(participant_path, "*.xlsx")

        if "output-new" in file_list:
            output_new_path = os.path.join(participant_path, "output-new")
            shutil.rmtree(output_new_path)
        if "temp" in file_list:
            temp_path = os.path.join(participant_path, "temp")
            shutil.rmtree(temp_path)

        move_files(kfa_path, participant_path, "*.wav")
        move_files(kfa_path, participant_path, "*.TextGrid")
        #move_files(kfa_path, participant_path, "*.lab")
        #move_files(kfa_path, participant_path, "*.txt")

        shutil.rmtree(kfa_path)
    else:
        shutil.rmtree(participant_path)
# Out:
# 삭제 완료: 02_stage1_20250404_1349.wav
# 삭제 완료: 02_stage6_20250404_1401.wav
# 삭제 완료: 02_stage2_20250404_1349.wav
# 삭제 완료: 02_stage3_20250404_1350.wav
# 삭제 완료: 02_stage5_20250404_1357.wav
# 삭제 완료: 02_stage4_20250404_1351.wav
# 총 6개의 파일 삭제가 완료되었습니다.
# 삭제 완료:
wav
# 총 6개의 파일 삭제가 완료되었습니다.
# 삭제 완료: 7_stage2_20250403_1944.TextGrid
# 삭제 완료: 7_stage1_20250403_1944.TextGrid
# 삭제 완료: 7_stage5_20250403_1951.TextGrid
# 삭제 완료: 7_stage3_20250403_1946.TextGrid
# 삭제 완료: 7_stage6_20250403_1956.TextGrid
# 삭제 완료: 7_stage4_20250403_1946.TextGrid
# 총 6개의 파일 삭제가 완료되었습니다.
# 총 0개의 파일 삭제가 완료되었습니다.
# 삭제 완료: 7_stage2_20250403_1944.txt
# 삭제 완료: 7_stage6_20250403_1956.txt
# 삭제 완료: 7_stage3_20250403_1946.txt
# 삭제 완료: 7_stage5_20250403_1951.txt
# 삭제 완료: 7_stage1_20250403_1944.txt
# 삭제 완료: 7_stage4_20250403_1946.txt
# 총 6개의 파일 삭제가 완료되었습니다.
# 삭제 완료: 7_stage6_20250403_1956.csv
# 삭제 완료: 7_stage2_20250403_1944.csv
# 삭제 완료: 7_stage3_20250403_1946.csv
# 삭제 완료: 7_stage5_20250403_1951.csv
# 삭제 완료: 7_stage1_20250403_1944.csv
# 삭제 완료: 7_stage4_20250403_1946.csv
# 총 6개의 파일 삭제가 완료되었습니다.
# 삭제 완료: 7_experiment_data.xlsx
# 총 1개의 파일 삭제가 완료되었습니다.
# 이동 완료: 7_stage6_20250403_1956.wav
# 이동 완료: 7_stage2_20250403_1944.wav
# 이동 완료: 7_stage5_20250403_1951.wav
# 이동 완료: 7_stage4_20250403_1946.wav
# 총 4개의 파일 이동이 완료되었습니다.
# 이동 완료: 7_stage2_20250403_1944.TextGrid
# 이동 완료: 7_stage5_20250403_1951.TextGrid
# 이동 완료: 7_stage6_20250403_1956.TextGrid
# 이동 완료: 7_stage4_20250403_1946.TextGrid
# 총 4개의 파일 이동이 완료되었습니다.
# 삭제 완료: LY08_stage3_20250501_1535.wav
# 삭제 완료: LY08_stage5_20250501_1541.wav
# 삭제 완료: LY08_stage2_20250501_1534.wav
# 삭제 완료: LY08_stage4_20250501_1536.wav
# 삭제 완료: LY08_stage1_20250501_1534.wav
# 삭제 완료: LY08_stage6_20250501_1545.wav
# 총 6개의 파일 삭제가 완료되었습니다.
# 총 0개의 파일 삭제가 완료되었습니다.
# 총 0개의 파일 삭제가 완료되었습니다.
# 삭제 완료: LY08_stage3_20250501_1535.txt
# 삭제 완료: LY08_stage5_20250501_1541.txt
# 삭제 완료: LY08_stage2_20250501_1534.txt
# 삭제 완료: LY08_stage4_20250501_1536.txt
# 삭제 완료: LY08_stage1_20250501_1534.txt
# 삭제 완료: LY08_stage6_20250501_1545.txt
# 총 6개의 파일 삭제가 완료되었습니다.
# 총 0개의 파일 삭제가 완료되었습니다.
# 삭제 완료: LY08_experiment_data.xlsx
# 총 1개의 파일 삭제가 완료되었습니다.
# 이동 완료: LY08_stage5_20250501_1541.wav
# 이동 완료: LY08_stage2_20250501_1534.wav
# 이동 완료: LY08_stage4_20250501_1536.wav
# 이동 완료: LY08_stage6_20250501_1545.wav
# 총 4개의 파일 이동이 완료되었습니다.
# 이동 완료: LY08_stage2_20250501_1534.TextGrid
# 이동 완료: LY08_stage6_20250501_1545.TextGrid
# 이동 완료: LY08_stage5_20250501_1541.TextGrid
# 이동 완료: LY08_stage4_20250501_1536.TextGrid
# 총 4개의 파일 이동이 완료되었습니다.
# 삭제 완료: LY09_stage5_20250408_1118.wav
# 삭제 완료: LY09_stage6_20250408_1123.wav
# 삭제 완료: LY09_stage3_20250408_1114.wav
# 삭제 완료: LY09_stage2_20250408_1113.wav
# 삭제 완료: LY09_stage4_20250408_1114.wav
# 삭제 완료: LY09_stage1_20250408_1112.wav
# 총 6개의 파일 삭제가 완료되었습니다.
# 삭제 완료: LY09_stage1_20250408_1112.TextGrid
# 삭제 완료: LY09_stage3_20250408_1114.TextGrid
# 삭제 완료: LY09_stage5_20250408_1118.TextGrid
# 삭제 완료: LY09_stage2_20250408_1113.TextGrid
# 삭제 완료: LY09_stage4_20250408_1114.TextGrid
# 삭제 완료: LY09_stage6_20250408_1123.TextGrid
# 총 6개의 파일 삭제가 완료되었습니다.
# 총 0개의 파일 삭제가 완료되었습니다.
# 삭제 완료: L
# 총 6개의 파일 삭제가 완료되었습니다.
# 총 0개의 파일 삭제가 완료되었습니다.
# 총 0개의 파일 삭제가 완료되었습니다.
# 삭제 완료: LY48_stage6_20250522_1501.txt
# 삭제 완료: LY48_stage3_20250522_1452.txt
# 삭제 완료: LY48_stage2_20250522_1450.txt
# 삭제 완료: LY48_stage4_20250522_1452.txt
# 삭제 완료: LY48_stage1_20250522_1450.txt
# 삭제 완료: LY48_stage5_20250522_1457.txt
# 총 6개의 파일 삭제가 완료되었습니다.
# 총 0개의 파일 삭제가 완료되었습니다.
# 삭제 완료: LY48_experiment_data.xlsx
# 총 1개의 파일 삭제가 완료되었습니다.
# 이동 완료: LY48_stage6_20250522_1501.wav
# 이동 완료: LY48_stage2_20250522_1450.wav
# 이동 완료: LY48_stage5_20250522_1457.wav
# 이동 완료: LY48_stage4_20250522_1452.wav
# 총 4개의 파일 이동이 완료되었습니다.
# 이동 완료: LY48_stage4_20250522_1452.TextGrid
# 이동 완료: LY48_stage2_20250522_1450.TextGrid
# 이동 완료: LY48_stage5_20250522_1457.TextGrid
# 이동 완료: LY48_stage6_20250522_1501.TextGrid
# 총 4개의 파일 이동이 완료되었습니다.

# %% [markdown]
# # control 조건 음성 파일 KFA 돌릴 준비

# %%
import os

audio_path = "/Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA"
audio_files = os.listdir(audio_path)
audio_files = [audio_file for audio_file in audio_files if audio_file.endswith(".wav")]
audio_files.sort()

# %%
data = {}

# %%
audio_files[0].replace('.wav', '')
# Out:
# '난색'

# %%
for audio_file in audio_files:
    audio_file_path = os.path.join(audio_path, audio_file)
    txt_name = audio_file.replace('.wav', '')
    txt_path = os.path.join(audio_path, txt_name + '.txt')
    
    # 명시적으로 UTF-8 인코딩과 LF 줄 끝 문자 사용
    with open(txt_path, 'w', encoding='utf-8', newline='\n') as f:
        f.write(txt_name)
    print(txt_path)
# Out:
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/난색.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/난파.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/내빈.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/내사.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/녹각.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/논개.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/누룩.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/누진.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/닌자.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/닝닝.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/말미.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/망루.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/매복.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/맹호.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/몰딩.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/몽매.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/무골.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/무운.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/미비.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/밀사.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/박애.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/발탁.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/백태.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/뱃심.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/복시.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/봉독.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/분개.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/불모.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/비재.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/빈축.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/상기.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/상록.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/새참.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/샐쭉.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/소조.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/송부.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/수하.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/술책.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/시문.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/실족.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/파군.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/판본.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/패물.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/팽배.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/포문.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/폭압.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/품띠.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/풍산.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/피폭.txt
# /Users/bagjuhyeon/Documents/WorkSpace/phoneticConvergence/audio-sample/short-version-phonetic/output-KFA/필생.txt

# %%
for audio_file in audio_files:
    audio_file_path = os.path.join(audio_path, audio_file)
    txt_name = audio_file.replace('.wav', '')
    txt_path = audio_path + '/'+ txt_name + '.txt'
    
    with open(txt_path, 'r') as f:
        print(f.read())
# Out:
# 난색
# 난파
# 내빈
# 내사
# 녹각
# 논개
# 누룩
# 누진
# 닌자
# 닝닝
# 말미
# 망루
# 매복
# 맹호
# 몰딩
# 몽매
# 무골
# 무운
# 미비
# 밀사
# 박애
# 발탁
# 백태
# 뱃심
# 복시
# 봉독
# 분개
# 불모
# 비재
# 빈축
# 상기
# 상록
# 새참
# 샐쭉
# 소조
# 송부
# 수하
# 술책
# 시문
# 실족
# 파군
# 판본
# 패물
# 팽배
# 포문
# 폭압
# 품띠
# 풍산
# 피폭
# 필생

# %%
def inspect_file(file_path):
    """
    파일의 바이트 단위 내용을 확인하는 함수
    """
    print(f"\n파일 경로: {file_path}")
    print(f"파일 크기: {os.path.getsize(file_path)} bytes")
    
    # 바이트 단위로 파일 읽기
    with open(file_path, 'rb') as f:
        content = f.read()
    
    print("\n바이트 내용:")
    print(content)
    
    print("\n각 바이트의 16진수 값:")
    print(' '.join(f'{b:02x}' for b in content))

# 사용 예시
# Cursor로 만든 파일
inspect_file("../audio-sample/short-version-phonetic/output-KFA/text.txt")
# Python으로 만든 파일
inspect_file("../audio-sample/short-version-phonetic/output-KFA/난색.txt")
# Out:
# 파일 경로: ../audio-sample/short-version-phonetic/output-KFA/text.txt
# 파일 크기: 6 bytes
#
# 바이트 내용:
# b'\xed\x8c\xbd\xeb\xb0\xb0'
#
# 각 바이트의 16진수 값:
# ed 8c bd eb b0 b0
#
# 파일 경로: ../audio-sample/short-version-phonetic/output-KFA/난색.txt
# 파일 크기: 18 bytes
#
# 바이트 내용:
# b'\xe1\x84\x82\xe1\x85\xa1\xe1\x86\xab\xe1\x84\x89\xe1\x85\xa2\xe1\x86\xa8'
#
# 각 바이트의 16진수 값:
# e1 84 82 e1 85 a1 e1 86 ab e1 84 89 e1 85 a2 e1 86 a8

# %%
def clean_text_file(input_path, output_path=None):
    """
    텍스트 파일의 보이지 않는 문자를 제거하고 정리하는 함수
    
    Args:
        input_path (str): 입력 파일 경로
        output_path (str, optional): 출력 파일 경로 (None이면 입력 파일을 덮어씀)
    """
    try:
        # 파일 읽기
        with open(input_path, 'r', encoding='utf-8') as f:
            content = f.read()
        
        # 줄 끝 문자를 LF로 통일
        content = content.replace('\r\n', '\n')
        
        # 연속된 공백 제거
        lines = content.split('\n')
        cleaned_lines = []
        
        for line in lines:
            # 줄 끝 공백 제거
            line = line.rstrip()
            # 연속된 공백을 하나로 통일
            line = ' '.join(line.split())
            cleaned_lines.append(line)
        
        # 빈 줄 제거
        cleaned_lines = [line for line in cleaned_lines if line.strip()]
        
        # 정리된 내용을 하나의 문자열로 합치기
        cleaned_content = '\n'.join(cleaned_lines)
        
        # 출력 파일 경로가 지정되지 않은 경우 입력 파일을 덮어씀
        if output_path is None:
            output_path = input_path
        
        # 파일 저장 (BOM 없이)
        with open(output_path, 'w', encoding='utf-8', newline='\n') as f:
            f.write(cleaned_content)
            
        print(f"파일 정리가 완료되었습니다: {output_path}")
        
    except Exception as e:
        print(f"에러 발생: {str(e)}")

# 사용 예시
if __name__ == "__main__":
    # 같은 파일을 덮어쓰기
    clean_text_file("../audio-sample/short-version-phonetic/output-KFA/난색.txt")
    
    # 다른 파일로 저장
    #clean_text_file("input.txt", "cleaned_output.txt")
# Out:
# 파일 정리가 완료되었습니다: ../audio-sample/short-version-phonetic/output-KFA/난색.txt
